# %%
import os
os.chdir('../')

from utils_network.data_generator import DataGenerator
from utils.other_utils import get_data

import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
PATH_PRED = '/home/michele/Documents/PhD_Sussex/output/ML/outputs/outputs_Segnet/inputs/data2D_128_180320_train/' 
X, y = get_data(PATH_PRED+'data/', (128,128,128))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-8c7aa586fe50> in <module>
#       1 PATH_PRED = '/home/michele/Documents/PhD_Sussex/output/ML/outputs/outputs_Segnet/inputs/data2D_128_180320_train/'
# ----> 2 X, y = get_data(PATH_PRED+'data/', (128,128,128))
#
# ~/Documents/PhD_Sussex/output/ML/SegNet/utils/other_utils.py in get_data(path, img_shape)
#      25     size = len(glob(path+'images*'))
#      26
# ---> 27     X = np.zeros(np.append(size, img_shape), dtype=np.float32)
#      28     Y = np.zeros(np.append(size, img_shape), dtype=np.float32)
#      29
#
# MemoryError:

# %%
generator = DataGenerator(data=X[:1,...], label=y[:1,...], batch_size=1, rotate_axis='random', rotate_angle='random', shuffle=True)
gen = generator.__getitem__(index=0)
# Out:
# 3 (1, 2)
# 3 (1, 2)

# %%
plt.imshow(gen[0][0][2,:,:].squeeze(), cmap='jet')
plt.show(), plt.clf()
plt.imshow(X[0,2,:,:,0].squeeze(), cmap='jet')
plt.show(), plt.clf()
plt.imshow(gen[1][0][2,:,:].squeeze(), cmap='jet')
plt.show(), plt.clf()
plt.imshow(y[0,2,:,:,0].squeeze(), cmap='jet')
plt.show(), plt.clf()
# Out:
# (None, None)

# %%
 np.zeros((np.append(32, (64,64,64))))[:-1].shape
# Out:
# (31, 64, 64, 64)

# %%
(32,64,64,64,1)[:-1]
# Out:
# (32, 64, 64, 64)

# %%
X[:1,...].shape
# Out:
# (1, 64, 64, 64, 1)

# %%
from PIL import Image, ImageDraw 
from tools21cm import save_cbin
import numpy as np

image = Image.new('RGB', size=(128, 128), color=(0,0,0)) 
draw = ImageDraw.Draw(image) 
r = 35
draw.ellipse((70-r, 70-r, 70+r, 70+r), fill=(255,255,255))
draw.ellipse((35-r*0.6, 45-r*0.6, 35+r*0.6, 45+r*0.6), fill=(255,255,255)) 
#image.show()

img = np.array(image, dtype=np.float)[:,:,0]
#save_cbin('circle.bin', img)

# %%
area_white = len(img[img!=0].flatten())
area_black = len(img[img==0].flatten())
area_tot = len(img.flatten())
print('mask area: %.2f %%' %(100*area_white/area_tot))
print(img.shape)
# Out:
# mask area: 31.08 %
# (128, 128)

# %%
img_rot = Image.fromarray(np.rot90(img, k=1))
img_rot.show()
