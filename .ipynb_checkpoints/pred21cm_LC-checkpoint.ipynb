# %%
import numpy as np, matplotlib.pyplot as plt, os
import tools21cm as t2c, py21cmfast as p21c
from py21cmfast import plotting
import random, zipfile
from astropy.cosmology import FlatLambdaCDM
from tqdm import tqdm

import matplotlib.gridspec as gridspec

from itertools import permutations
from datetime import datetime

# create seed for 21cmFast
str_seed = [var for var in datetime.now().strftime('%d%H%M%S')]
np.random.shuffle(str_seed)
seed = int(''.join(str_seed))

from astropy.cosmology import FlatLambdaCDM
from astropy import units as u
from astropy import constants as c

#outpath = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/inputs/test_predict/'
outpath = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/15-06T22-53-20_128LC/predictions/'

# %%
eff_fact = random.gauss(52.5, 20.)
Rmfp = random.gauss(12.5, 5.)
Tvir = random.gauss(4.65, 0.5)

str_seed = [var for var in datetime.now().strftime('%d%H%M%S')]
np.random.shuffle(str_seed)
seed = int(''.join(str_seed))

print(eff_fact, Rmfp, Tvir, seed)
# Out:
# 53.72226764014074 12.324838622153065 4.442478850793177 9120316

# %%
#rseed = 20223
rseed = 2022
z_min = 7
z_max = 11
eff_fact = 42.580
Rmfp = 12.861
Tvir = 4.539

params = {'HII_DIM':128, 'DIM':384, 'BOX_LEN':256}
my_ext = [0, params['BOX_LEN'], 0, params['BOX_LEN']]
c_params = {'OMm':0.27, 'OMb':0.046, 'SIGMA_8':0.82, 'POWER_INDEX':0.96}
cosmo = FlatLambdaCDM(H0=70., Ob0=c_params['OMb'], Om0=c_params['OMm'])
a_params = {'HII_EFF_FACTOR':eff_fact, 'R_BUBBLE_MAX':Rmfp, 'ION_Tvir_MIN':Tvir}

def BoxQuantity(cL, z):
    dthet = (((cL*u.Mpc/cosmo.h)/((1+z)*cosmo.angular_diameter_distance(z)))*u.rad).to(u.arcmin)
    dnu = (1.42*u.GHz*cosmo.H(z)*(cL*u.Mpc/cosmo.h)/(c.c*(1+z)**2)).to(u.MHz)
    return dthet, dnu

lightcone = p21c.run_lightcone(redshift=z_min, max_redshift=z_max, astro_params=a_params, cosmo_params=c_params, user_params=params, lightcone_quantities=("brightness_temp", 'xH_box'), direc='_cache', random_seed=rseed)

# %%
dataLC, redshiftLC = lightcone.brightness_temp, lightcone.lightcone_redshifts
dataLC_xH = lightcone.xH_box

# %% [markdown]
# ## Create Lightcone
# Here we create the 21cmFast cube outputs

# %%
zeta = 65.204
Rmfp = 11.861
Tvir = 4.539

params = {'HII_DIM':128, 'DIM':384, 'BOX_LEN':256}
my_ext = [0, params['BOX_LEN'], 0, params['BOX_LEN']]
c_params = {'OMm':0.27, 'OMb':0.046, 'SIGMA_8':0.82, 'POWER_INDEX':0.96}
a_params = {'HII_EFF_FACTOR':zeta, 'R_BUBBLE_MAX':Rmfp, 'ION_Tvir_MIN':Tvir}
cosmo = FlatLambdaCDM(H0=70., Ob0=c_params['OMb'], Om0=c_params['OMm'])

#if not (os.path.exists(outpath+'dataLC.bin')):
if not (False):
    print('Create Lightcone data')
    lightcone = p21c.run_lightcone(redshift=7.0, max_redshift=12.0, astro_params=a_params, cosmo_params=c_params, user_params=params, lightcone_quantities=("brightness_temp", 'xH_box'), direc='/home/michele/21CMMC_Boxes', random_seed=2020, cleanup=True) 

    dataLC, redshiftLC = lightcone.brightness_temp, lightcone.lightcone_redshifts
    dataLC_xH = lightcone.xH_box

    t2c.save_cbin(outpath+'dataLC.bin', dataLC)
    np.savetxt(outpath+'redshiftLC.txt', redshiftLC)
    t2c.save_cbin(outpath+'dataLC_xH.bin', dataLC_xH)
else:
    print('Open Lightcone data')
    dataLC = t2c.read_cbin(outpath+'dataLC.bin')
    redshiftLC = np.loadtxt(outpath+'redshiftLC.txt')
    dataLC_xH = t2c.read_cbin(outpath+'dataLC_xH.bin')


print('zeta = %.3f  R_mfp = %.3f  T_vir = %.3f' %(zeta, Rmfp, Tvir))
# Out:
# Create Lightcone data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4aee5760f311> in <module>
#      17     dataLC_xH = lightcone.xH_box
#      18
# ---> 19     t2c.save_cbin(outpath+'dataLC.bin', dataLC)
#      20     np.savetxt(outpath+'redshiftLC.txt', redshiftLC)
#      21     t2c.save_cbin(outpath+'dataLC_xH.bin', dataLC_xH)
#
# ~/python/anaconda/lib/python3.7/site-packages/tools21cm/helper_functions.py in save_cbin(filename, data, bits, order)
#     223         print_msg('Saving cbin file: %s' % filename)
#     224         assert(bits ==32 or bits==64)
# --> 225         f = open(filename, 'wb')
#     226         mesh = np.array(data.shape).astype('int32')
#     227         mesh.tofile(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/15-06T22-53-20_128LC/predictions/dataLC.bin'

# %%
uvfile = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/inputs/uvmap_128_z7-20.pkl'
if not (os.path.exists(uvfile)):
    print('uv-map pickle not found')

# %% [markdown]
# ## Plot $x_{HI}$ and $\delta T_b$ Lightcone

# %%
LC_xH, _ = t2c.smooth_lightcone(lightcone=dataLC_xH, z_array=redshiftLC, box_size_mpc=params['BOX_LEN'])
mask_LCxH = (LC_xH>0.5).astype(int)

# %%
LC1 = t2c.subtract_mean_signal(dataLC, los_axis=2)
noise_cone = t2c.noise_lightcone(ncells=LC1.shape[0], zs=redshiftLC, obs_time=1000, boxsize=params['BOX_LEN'], n_jobs=1, save_uvmap=uvfile)
LC3, redshiftLC3 = t2c.smooth_lightcone(lightcone=LC1+noise_cone, z_array=redshiftLC, box_size_mpc=params['BOX_LEN'])
# Out:
# All or some uv maps is read from the given file. Be sure that they were run with the same parameter values as provided now.
# Creating the uv maps.
#
# z = 7.000 | 0.18 % completed | Elapsed time: 0.00 mins
#
# z = 7.005 | 0.36 % completed | Elapsed time: 0.00 mins
#
# z = 7.011 | 0.54 % completed | Elapsed time: 0.00 mins
#
# z = 7.016 | 0.72 % completed | Elapsed time: 0.00 mins
#
# z = 7.021 | 0.91 % completed | Elapsed time: 0.00 mins
#
# z = 7.027 | 1.09 % completed | Elapsed time: 0.00 mins
#
# z = 7.032 | 1.27 % completed | Elapsed time: 0.00 mins
#
# z = 7.038 | 1.45 % completed | Elapsed time: 0.00 mins
#
# z = 7.043 | 1.63 % completed | Elapsed time: 0.00 mins
#
# z = 7.048 | 1.81 % completed | Elapsed time: 0.00 mins
#
# z = 7.054 | 1.99 % completed | Elapsed time: 0.00 mins
#
# z = 7.059 | 2.17 % completed | Elapsed time: 0.00 mins
#
# z = 7.065 | 2.36 % completed | Elapsed time: 0.00 mins
#
# z = 7.070 | 2.54 % completed | Elapsed time: 0.00 mins
#
# z = 7.075 | 2.72 % completed | Elapsed time: 0.00 mins
#
# z = 7.081 | 2.90 % completed | Elapsed time: 0.00 mins
#
# z = 7.086 | 3.08 % completed | Elapsed time: 0.00 mins
#
# z = 7.092 | 3.26 % completed | Elapsed time: 0.00 mins
#
# z = 7.097 | 3.44 % completed | Elapsed time: 0.00 mins
#
# z = 7.103 | 3.62 % completed | Elapsed time: 0.00 mins
#
# z = 7.108 | 3.80 % completed | Elapsed time: 0.00 mins
#
# z = 7.114 | 3.99 % completed | Elapsed time: 0.00 mins
#
# z = 7.119 | 4.17 % completed | Elapsed time: 0.00 mins
#
# z = 7.124 | 4.35 % completed | Elapsed time: 0.00 mins
#
# z = 7.130 | 4.53 % completed | Elapsed time: 0.00 mins
#
# z = 7.135 | 4.71 % completed | Elapsed time: 0.00 mins
#
# z = 7.141 | 4.89 % completed | Elapsed time: 0.00 mins
#
# z = 7.146 | 5.07 % completed | Elapsed time: 0.00 mins
#
# z = 7.152 | 5.25 % completed | Elapsed time: 0.00 mins
#
# z = 7.157 | 5.43 % completed | Elapsed time: 0.00 mins
#
# z = 7.163 | 5.62 % completed | Elapsed time: 0.00 mins
#
# z = 7.168 | 5.80 % completed | Elapsed time: 0.00 mins
#
# z = 7.174 | 5.98 % completed | Elapsed time: 0.00 mins
#
# z = 7.180 | 6.16 % completed | Elapsed time: 0.00 mins
#
# z = 7.185 | 6.34 % completed | Elapsed time: 0.00 mins
#
# z = 7.191 | 6.52 % completed | Elapsed time: 0.00 mins
#
# z = 7.196 | 6.70 % completed | Elapsed time: 0.00 mins
#
# z = 7.202 | 6.88 % completed | Elapsed time: 0.00 mins
#
# z = 7.207 | 7.07 % completed | Elapsed time: 0.00 mins
#
# z = 7.213 | 7.25 % completed | Elapsed time: 0.00 mins
#
# z = 7.218 | 7.43 % completed | Elapsed time: 0.00 mins
#
# z = 7.224 | 7.61 % completed | Elapsed time: 0.00 mins
#
# z = 7.230 | 7.79 % completed | Elapsed time: 0.00 mins
#
# z = 7.235 | 7.97 % completed | Elapsed time: 0.00 mins
#
# z = 7.241 | 8.15 % completed | Elapsed time: 0.00 mins
#
# z = 7.246 | 8.33 % completed | Elapsed time: 0.00 mins
#
# z = 7.252 | 8.51 % completed | Elapsed time: 0.00 mins
#
# z = 7.258 | 8.70 % completed | Elapsed time: 0.00 mins
#
# z = 7.263 | 8.88 % completed | Elapsed time: 0.00 mins
#
# z = 7.269 | 9.06 % completed | Elapsed time: 0.00 mins
#
# z = 7.274 | 9.24 % completed | Elapsed time: 0.00 mins
#
# z = 7.280 | 9.42 % completed | Elapsed time: 0.00 mins
#
# z = 7.286 | 9.60 % completed | Elapsed time: 0.00 mins
#
# z = 7.291 | 9.78 % completed | Elapsed time: 0.00 mins
#
# z = 7.297 | 9.96 % completed | Elapsed time: 0.00 mins
#
# z = 7.303 | 10.14 % completed | Elapsed time: 0.00 mins
#
# z = 7.308 | 10.33 % completed | Elapsed time: 0.00 mins
#
# z = 7.314 | 10.51 % completed | Elapsed time: 0.00 mins
#
# z = 7.320 | 10.69 % completed | Elapsed time: 0.00 mins
#
# z = 7.325 | 10.87 % completed | Elapsed time: 0.00 mins
#
# z = 7.331 | 11.05 % completed | Elapsed time: 0.00 mins
#
# z = 7.337 | 11.23 % completed | Elapsed time: 0.00 mins
#
# z = 7.342 | 11.41 % completed | Elapsed time: 0.00 mins
#
# z = 7.348 | 11.59 % completed | Elapsed time: 0.00 mins
#
# z = 7.354 | 11.78 % completed | Elapsed time: 0.00 mins
#
# z = 7.359 | 11.96 % completed | Elapsed time: 0.00 mins
#
# z = 7.365 | 12.14 % completed | Elapsed time: 0.00 mins
#
# z = 7.371 | 12.32 % completed | Elapsed time: 0.00 mins
#
# z = 7.377 | 12.50 % completed | Elapsed time: 0.00 mins
#
# z = 7.382 | 12.68 % completed | Elapsed time: 0.00 mins
#
# z = 7.388 | 12.86 % completed | Elapsed time: 0.00 mins
#
# z = 7.394 | 13.04 % completed | Elapsed time: 0.00 mins
#
# z = 7.400 | 13.22 % completed | Elapsed time: 0.00 mins
#
# z = 7.405 | 13.41 % completed | Elapsed time: 0.00 mins
#
# z = 7.411 | 13.59 % completed | Elapsed time: 0.00 mins
#
# z = 7.417 | 13.77 % completed | Elapsed time: 0.00 mins
#
# z = 7.423 | 13.95 % completed | Elapsed time: 0.00 mins
#
# z = 7.428 | 14.13 % completed | Elapsed time: 0.00 mins
#
# z = 7.434 | 14.31 % completed | Elapsed time: 0.00 mins
#
# z = 7.440 | 14.49 % completed | Elapsed time: 0.00 mins
#
# z = 7.446 | 14.67 % completed | Elapsed time: 0.00 mins
#
# z = 7.452 | 14.86 % completed | Elapsed time: 0.00 mins
#
# z = 7.457 | 15.04 % completed | Elapsed time: 0.00 mins
#
# z = 7.463 | 15.22 % completed | Elapsed time: 0.00 mins
#
# z = 7.469 | 15.40 % completed | Elapsed time: 0.00 mins
#
# z = 7.475 | 15.58 % completed | Elapsed time: 0.00 mins
#
# z = 7.481 | 15.76 % completed | Elapsed time: 0.00 mins
#
# z = 7.487 | 15.94 % completed | Elapsed time: 0.00 mins
#
# z = 7.492 | 16.12 % completed | Elapsed time: 0.00 mins
#
# z = 7.498 | 16.30 % completed | Elapsed time: 0.00 mins
#
# z = 7.504 | 16.49 % completed | Elapsed time: 0.00 mins
#
# z = 7.510 | 16.67 % completed | Elapsed time: 0.00 mins
#
# z = 7.516 | 16.85 % completed | Elapsed time: 0.00 mins
#
# z = 7.522 | 17.03 % completed | Elapsed time: 0.00 mins
#
# z = 7.528 | 17.21 % completed | Elapsed time: 0.00 mins
#
# z = 7.534 | 17.39 % completed | Elapsed time: 0.00 mins
#
# z = 7.539 | 17.57 % completed | Elapsed time: 0.00 mins
#
# z = 7.545 | 17.75 % completed | Elapsed time: 0.00 mins
#
# z = 7.551 | 17.93 % completed | Elapsed time: 0.00 mins
#
# z = 7.557 | 18.12 % completed | Elapsed time: 0.00 mins
#
# z = 7.563 | 18.30 % completed | Elapsed time: 0.00 mins
#
# z = 7.569 | 18.48 % completed | Elapsed time: 0.00 mins
#
# z = 7.575 | 18.66 % completed | Elapsed time: 0.00 mins
#
# z = 7.581 | 18.84 % completed | Elapsed time: 0.00 mins
#
# z = 7.587 | 19.02 % completed | Elapsed time: 0.00 mins
#
# z = 7.593 | 19.20 % completed | Elapsed time: 0.00 mins
#
# z = 7.599 | 19.38 % completed | Elapsed time: 0.00 mins
#
# z = 7.605 | 19.57 % completed | Elapsed time: 0.00 mins
#
# z = 7.611 | 19.75 % completed | Elapsed time: 0.00 mins
#
# z = 7.617 | 19.93 % completed | Elapsed time: 0.00 mins
#
# z = 7.623 | 20.11 % completed | Elapsed time: 0.00 mins
#
# z = 7.629 | 20.29 % completed | Elapsed time: 0.00 mins
#
# z = 7.635 | 20.47 % completed | Elapsed time: 0.00 mins
#
# z = 7.641 | 20.65 % completed | Elapsed time: 0.00 mins
#
# z = 7.647 | 20.83 % completed | Elapsed time: 0.00 mins
#
# z = 7.653 | 21.01 % completed | Elapsed time: 0.00 mins
#
# z = 7.659 | 21.20 % completed | Elapsed time: 0.00 mins
#
# z = 7.665 | 21.38 % completed | Elapsed time: 0.00 mins
#
# z = 7.671 | 21.56 % completed | Elapsed time: 0.00 mins
#
# z = 7.677 | 21.74 % completed | Elapsed time: 0.00 mins
#
# z = 7.683 | 21.92 % completed | Elapsed time: 0.00 mins
#
# z = 7.689 | 22.10 % completed | Elapsed time: 0.00 mins
#
# z = 7.695 | 22.28 % completed | Elapsed time: 0.00 mins
#
# z = 7.701 | 22.46 % completed | Elapsed time: 0.00 mins
#
# z = 7.707 | 22.64 % completed | Elapsed time: 0.00 mins
#
# z = 7.713 | 22.83 % completed | Elapsed time: 0.00 mins
#
# z = 7.719 | 23.01 % completed | Elapsed time: 0.00 mins
#
# z = 7.725 | 23.19 % completed | Elapsed time: 0.00 mins
#
# z = 7.731 | 23.37 % completed | Elapsed time: 0.00 mins
#
# z = 7.737 | 23.55 % completed | Elapsed time: 0.00 mins
#
# z = 7.744 | 23.73 % completed | Elapsed time: 0.00 mins
#
# z = 7.750 | 23.91 % completed | Elapsed time: 0.00 mins
#
# z = 7.756 | 24.09 % completed | Elapsed time: 0.00 mins
#
# z = 7.762 | 24.28 % completed | Elapsed time: 0.00 mins
#
# z = 7.768 | 24.46 % completed | Elapsed time: 0.00 mins
#
# z = 7.774 | 24.64 % completed | Elapsed time: 0.00 mins
#
# z = 7.780 | 24.82 % completed | Elapsed time: 0.00 mins
#
# z = 7.786 | 25.00 % completed | Elapsed time: 0.00 mins
#
# z = 7.793 | 25.18 % completed | Elapsed time: 0.00 mins
#
# z = 7.799 | 25.36 % completed | Elapsed time: 0.00 mins
#
# z = 7.805 | 25.54 % completed | Elapsed time: 0.00 mins
#
# z = 7.811 | 25.72 % completed | Elapsed time: 0.00 mins
#
# z = 7.817 | 25.91 % completed | Elapsed time: 0.00 mins
#
# z = 7.824 | 26.09 % completed | Elapsed time: 0.00 mins
#
# z = 7.830 | 26.27 % completed | Elapsed time: 0.00 mins
#
# z = 7.836 | 26.45 % completed | Elapsed time: 0.00 mins
#
# z = 7.842 | 26.63 % completed | Elapsed time: 0.00 mins
#
# z = 7.848 | 26.81 % completed | Elapsed time: 0.00 mins
#
# z = 7.855 | 26.99 % completed | Elapsed time: 0.00 mins
#
# z = 7.861 | 27.17 % completed | Elapsed time: 0.00 mins
#
# z = 7.867 | 27.36 % completed | Elapsed time: 0.00 mins
#
# z = 7.873 | 27.54 % completed | Elapsed time: 0.00 mins
#
# z = 7.880 | 27.72 % completed | Elapsed time: 0.00 mins
#
# z = 7.886 | 27.90 % completed | Elapsed time: 0.00 mins
#
# z = 7.892 | 28.08 % completed | Elapsed time: 0.00 mins
#
# z = 7.898 | 28.26 % completed | Elapsed time: 0.00 mins
#
# z = 7.905 | 28.44 % completed | Elapsed time: 0.00 mins
#
# z = 7.911 | 28.62 % completed | Elapsed time: 0.00 mins
#
# z = 7.917 | 28.80 % completed | Elapsed time: 0.00 mins
#
# z = 7.923 | 28.99 % completed | Elapsed time: 0.00 mins
#
# z = 7.930 | 29.17 % completed | Elapsed time: 0.00 mins
#
# z = 7.936 | 29.35 % completed | Elapsed time: 0.00 mins
#
# z = 7.942 | 29.53 % completed | Elapsed time: 0.00 mins
#
# z = 7.949 | 29.71 % completed | Elapsed time: 0.00 mins
#
# z = 7.955 | 29.89 % completed | Elapsed time: 0.00 mins
#
# z = 7.961 | 30.07 % completed | Elapsed time: 0.00 mins
#
# z = 7.968 | 30.25 % completed | Elapsed time: 0.00 mins
#
# z = 7.974 | 30.43 % completed | Elapsed time: 0.00 mins
#
# z = 7.980 | 30.62 % completed | Elapsed time: 0.00 mins
#
# z = 7.987 | 30.80 % completed | Elapsed time: 0.00 mins
#
# z = 7.993 | 30.98 % completed | Elapsed time: 0.00 mins
#
# z = 8.000 | 31.16 % completed | Elapsed time: 0.00 mins
#
# z = 8.006 | 31.34 % completed | Elapsed time: 0.00 mins
#
# z = 8.012 | 31.52 % completed | Elapsed time: 0.00 mins
#
# z = 8.019 | 31.70 % completed | Elapsed time: 0.00 mins
#
# z = 8.025 | 31.88 % completed | Elapsed time: 0.00 mins
#
# z = 8.032 | 32.07 % completed | Elapsed time: 0.00 mins
#
# z = 8.038 | 32.25 % completed | Elapsed time: 0.00 mins
#
# z = 8.044 | 32.43 % completed | Elapsed time: 0.00 mins
#
# z = 8.051 | 32.61 % completed | Elapsed time: 0.00 mins
#
# z = 8.057 | 32.79 % completed | Elapsed time: 0.00 mins
#
# z = 8.064 | 32.97 % completed | Elapsed time: 0.00 mins
#
# z = 8.070 | 33.15 % completed | Elapsed time: 0.00 mins
#
# z = 8.077 | 33.33 % completed | Elapsed time: 0.00 mins
#
# z = 8.083 | 33.51 % completed | Elapsed time: 0.00 mins
#
# z = 8.090 | 33.70 % completed | Elapsed time: 0.00 mins
#
# z = 8.096 | 33.88 % completed | Elapsed time: 0.00 mins
#
# z = 8.103 | 34.06 % completed | Elapsed time: 0.00 mins
#
# z = 8.109 | 34.24 % completed | Elapsed time: 0.00 mins
#
# z = 8.116 | 34.42 % completed | Elapsed time: 0.00 mins
#
# z = 8.122 | 34.60 % completed | Elapsed time: 0.00 mins
#
# z = 8.129 | 34.78 % completed | Elapsed time: 0.00 mins
#
# z = 8.135 | 34.96 % completed | Elapsed time: 0.00 mins
#
# z = 8.142 | 35.14 % completed | Elapsed time: 0.00 mins
#
# z = 8.148 | 35.33 % completed | Elapsed time: 0.00 mins
#
# z = 8.155 | 35.51 % completed | Elapsed time: 0.00 mins
#
# z = 8.161 | 35.69 % completed | Elapsed time: 0.00 mins
#
# z = 8.168 | 35.87 % completed | Elapsed time: 0.00 mins
#
# z = 8.174 | 36.05 % completed | Elapsed time: 0.00 mins
#
# z = 8.181 | 36.23 % completed | Elapsed time: 0.00 mins
#
# z = 8.187 | 36.41 % completed | Elapsed time: 0.00 mins
#
# z = 8.194 | 36.59 % completed | Elapsed time: 0.00 mins
#
# z = 8.201 | 36.78 % completed | Elapsed time: 0.00 mins
#
# z = 8.207 | 36.96 % completed | Elapsed time: 0.00 mins
#
# z = 8.214 | 37.14 % completed | Elapsed time: 0.00 mins
#
# z = 8.220 | 37.32 % completed | Elapsed time: 0.00 mins
#
# z = 8.227 | 37.50 % completed | Elapsed time: 0.00 mins
#
# z = 8.234 | 37.68 % completed | Elapsed time: 0.00 mins
#
# z = 8.240 | 37.86 % completed | Elapsed time: 0.00 mins
#
# z = 8.247 | 38.04 % completed | Elapsed time: 0.00 mins
#
# z = 8.254 | 38.22 % completed | Elapsed time: 0.00 mins
#
# z = 8.260 | 38.41 % completed | Elapsed time: 0.00 mins
#
# z = 8.267 | 38.59 % completed | Elapsed time: 0.00 mins
#
# z = 8.274 | 38.77 % completed | Elapsed time: 0.00 mins
#
# z = 8.280 | 38.95 % completed | Elapsed time: 0.00 mins
#
# z = 8.287 | 39.13 % completed | Elapsed time: 0.00 mins
#
# z = 8.294 | 39.31 % completed | Elapsed time: 0.00 mins
#
# z = 8.300 | 39.49 % completed | Elapsed time: 0.00 mins
#
# z = 8.307 | 39.67 % completed | Elapsed time: 0.00 mins
#
# z = 8.314 | 39.86 % completed | Elapsed time: 0.00 mins
#
# z = 8.321 | 40.04 % completed | Elapsed time: 0.00 mins
#
# z = 8.327 | 40.22 % completed | Elapsed time: 0.00 mins
#
# z = 8.334 | 40.40 % completed | Elapsed time: 0.00 mins
#
# z = 8.341 | 40.58 % completed | Elapsed time: 0.00 mins
#
# z = 8.347 | 40.76 % completed | Elapsed time: 0.00 mins
#
# z = 8.354 | 40.94 % completed | Elapsed time: 0.00 mins
#
# z = 8.361 | 41.12 % completed | Elapsed time: 0.00 mins
#
# z = 8.368 | 41.30 % completed | Elapsed time: 0.00 mins
#
# z = 8.375 | 41.49 % completed | Elapsed time: 0.00 mins
#
# z = 8.381 | 41.67 % completed | Elapsed time: 0.00 mins
#
# z = 8.388 | 41.85 % completed | Elapsed time: 0.00 mins
#
# z = 8.395 | 42.03 % completed | Elapsed time: 0.00 mins
#
# z = 8.402 | 42.21 % completed | Elapsed time: 0.00 mins
#
# z = 8.409 | 42.39 % completed | Elapsed time: 0.00 mins
#
# z = 8.415 | 42.57 % completed | Elapsed time: 0.00 mins
#
# z = 8.422 | 42.75 % completed | Elapsed time: 0.00 mins
#
# z = 8.429 | 42.93 % completed | Elapsed time: 0.00 mins
#
# z = 8.436 | 43.12 % completed | Elapsed time: 0.00 mins
#
# z = 8.443 | 43.30 % completed | Elapsed time: 0.00 mins
#
# z = 8.450 | 43.48 % completed | Elapsed time: 0.00 mins
#
# z = 8.456 | 43.66 % completed | Elapsed time: 0.00 mins
#
# z = 8.463 | 43.84 % completed | Elapsed time: 0.00 mins
#
# z = 8.470 | 44.02 % completed | Elapsed time: 0.00 mins
#
# z = 8.477 | 44.20 % completed | Elapsed time: 0.00 mins
#
# z = 8.484 | 44.38 % completed | Elapsed time: 0.00 mins
#
# z = 8.491 | 44.57 % completed | Elapsed time: 0.00 mins
#
# z = 8.498 | 44.75 % completed | Elapsed time: 0.00 mins
#
# z = 8.505 | 44.93 % completed | Elapsed time: 0.00 mins
#
# z = 8.512 | 45.11 % completed | Elapsed time: 0.00 mins
#
# z = 8.519 | 45.29 % completed | Elapsed time: 0.00 mins
#
# z = 8.526 | 45.47 % completed | Elapsed time: 0.00 mins
#
# z = 8.532 | 45.65 % completed | Elapsed time: 0.00 mins
#
# z = 8.539 | 45.83 % completed | Elapsed time: 0.00 mins
#
# z = 8.546 | 46.01 % completed | Elapsed time: 0.00 mins
#
# z = 8.553 | 46.20 % completed | Elapsed time: 0.00 mins
#
# z = 8.560 | 46.38 % completed | Elapsed time: 0.00 mins
#
# z = 8.567 | 46.56 % completed | Elapsed time: 0.00 mins
#
# z = 8.574 | 46.74 % completed | Elapsed time: 0.00 mins
#
# z = 8.581 | 46.92 % completed | Elapsed time: 0.00 mins
#
# z = 8.588 | 47.10 % completed | Elapsed time: 0.00 mins
#
# z = 8.595 | 47.28 % completed | Elapsed time: 0.00 mins
#
# z = 8.602 | 47.46 % completed | Elapsed time: 0.00 mins
#
# z = 8.609 | 47.64 % completed | Elapsed time: 0.00 mins
#
# z = 8.616 | 47.83 % completed | Elapsed time: 0.00 mins
#
# z = 8.624 | 48.01 % completed | Elapsed time: 0.00 mins
#
# z = 8.631 | 48.19 % completed | Elapsed time: 0.00 mins
#
# z = 8.638 | 48.37 % completed | Elapsed time: 0.00 mins
#
# z = 8.645 | 48.55 % completed | Elapsed time: 0.00 mins
#
# z = 8.652 | 48.73 % completed | Elapsed time: 0.00 mins
#
# z = 8.659 | 48.91 % completed | Elapsed time: 0.00 mins
#
# z = 8.666 | 49.09 % completed | Elapsed time: 0.00 mins
#
# z = 8.673 | 49.28 % completed | Elapsed time: 0.00 mins
#
# z = 8.680 | 49.46 % completed | Elapsed time: 0.00 mins
#
# z = 8.687 | 49.64 % completed | Elapsed time: 0.00 mins
#
# z = 8.694 | 49.82 % completed | Elapsed time: 0.00 mins
#
# z = 8.702 | 50.00 % completed | Elapsed time: 0.00 mins
#
# z = 8.709 | 50.18 % completed | Elapsed time: 0.00 mins
#
# z = 8.716 | 50.36 % completed | Elapsed time: 0.00 mins
#
# z = 8.723 | 50.54 % completed | Elapsed time: 0.00 mins
#
# z = 8.730 | 50.72 % completed | Elapsed time: 0.00 mins
#
# z = 8.737 | 50.91 % completed | Elapsed time: 0.00 mins
#
# z = 8.745 | 51.09 % completed | Elapsed time: 0.00 mins
#
# z = 8.752 | 51.27 % completed | Elapsed time: 0.00 mins
#
# z = 8.759 | 51.45 % completed | Elapsed time: 0.00 mins
#
# z = 8.766 | 51.63 % completed | Elapsed time: 0.00 mins
#
# z = 8.773 | 51.81 % completed | Elapsed time: 0.00 mins
#
# z = 8.781 | 51.99 % completed | Elapsed time: 0.00 mins
#
# z = 8.788 | 52.17 % completed | Elapsed time: 0.00 mins
#
# z = 8.795 | 52.36 % completed | Elapsed time: 0.00 mins
#
# z = 8.802 | 52.54 % completed | Elapsed time: 0.00 mins
#
# z = 8.810 | 52.72 % completed | Elapsed time: 0.00 mins
#
# z = 8.817 | 52.90 % completed | Elapsed time: 0.00 mins
#
# z = 8.824 | 53.08 % completed | Elapsed time: 0.00 mins
#
# z = 8.831 | 53.26 % completed | Elapsed time: 0.00 mins
#
# z = 8.839 | 53.44 % completed | Elapsed time: 0.00 mins
#
# z = 8.846 | 53.62 % completed | Elapsed time: 0.00 mins
#
# z = 8.853 | 53.80 % completed | Elapsed time: 0.00 mins
#
# z = 8.861 | 53.99 % completed | Elapsed time: 0.00 mins
#
# z = 8.868 | 54.17 % completed | Elapsed time: 0.00 mins
#
# z = 8.875 | 54.35 % completed | Elapsed time: 0.00 mins
#
# z = 8.883 | 54.53 % completed | Elapsed time: 0.00 mins
#
# z = 8.890 | 54.71 % completed | Elapsed time: 0.00 mins
#
# z = 8.897 | 54.89 % completed | Elapsed time: 0.00 mins
#
# z = 8.905 | 55.07 % completed | Elapsed time: 0.00 mins
#
# z = 8.912 | 55.25 % completed | Elapsed time: 0.00 mins
#
# z = 8.919 | 55.43 % completed | Elapsed time: 0.00 mins
#
# z = 8.927 | 55.62 % completed | Elapsed time: 0.00 mins
#
# z = 8.934 | 55.80 % completed | Elapsed time: 0.00 mins
#
# z = 8.942 | 55.98 % completed | Elapsed time: 0.00 mins
#
# z = 8.949 | 56.16 % completed | Elapsed time: 0.00 mins
#
# z = 8.956 | 56.34 % completed | Elapsed time: 0.00 mins
#
# z = 8.964 | 56.52 % completed | Elapsed time: 0.00 mins
#
# z = 8.971 | 56.70 % completed | Elapsed time: 0.00 mins
#
# z = 8.979 | 56.88 % completed | Elapsed time: 0.00 mins
#
# z = 8.986 | 57.07 % completed | Elapsed time: 0.00 mins
#
# z = 8.994 | 57.25 % completed | Elapsed time: 0.00 mins
#
# z = 9.001 | 57.43 % completed | Elapsed time: 0.00 mins
#
# z = 9.009 | 57.61 % completed | Elapsed time: 0.00 mins
#
# z = 9.016 | 57.79 % completed | Elapsed time: 0.00 mins
#
# z = 9.024 | 57.97 % completed | Elapsed time: 0.00 mins
#
# z = 9.031 | 58.15 % completed | Elapsed time: 0.00 mins
#
# z = 9.039 | 58.33 % completed | Elapsed time: 0.00 mins
#
# z = 9.046 | 58.51 % completed | Elapsed time: 0.00 mins
#
# z = 9.054 | 58.70 % completed | Elapsed time: 0.00 mins
#
# z = 9.061 | 58.88 % completed | Elapsed time: 0.00 mins
#
# z = 9.069 | 59.06 % completed | Elapsed time: 0.00 mins
#
# z = 9.076 | 59.24 % completed | Elapsed time: 0.00 mins
#
# z = 9.084 | 59.42 % completed | Elapsed time: 0.00 mins
#
# z = 9.091 | 59.60 % completed | Elapsed time: 0.00 mins
#
# z = 9.099 | 59.78 % completed | Elapsed time: 0.00 mins
#
# z = 9.106 | 59.96 % completed | Elapsed time: 0.00 mins
#
# z = 9.114 | 60.14 % completed | Elapsed time: 0.00 mins
#
# z = 9.122 | 60.33 % completed | Elapsed time: 0.00 mins
#
# z = 9.129 | 60.51 % completed | Elapsed time: 0.00 mins
#
# z = 9.137 | 60.69 % completed | Elapsed time: 0.00 mins
#
# z = 9.145 | 60.87 % completed | Elapsed time: 0.00 mins
#
# z = 9.152 | 61.05 % completed | Elapsed time: 0.00 mins
#
# z = 9.160 | 61.23 % completed | Elapsed time: 0.00 mins
#
# z = 9.167 | 61.41 % completed | Elapsed time: 0.00 mins
#
# z = 9.175 | 61.59 % completed | Elapsed time: 0.00 mins
#
# z = 9.183 | 61.78 % completed | Elapsed time: 0.00 mins
#
# z = 9.191 | 61.96 % completed | Elapsed time: 0.00 mins
#
# z = 9.198 | 62.14 % completed | Elapsed time: 0.00 mins
#
# z = 9.206 | 62.32 % completed | Elapsed time: 0.00 mins
#
# z = 9.214 | 62.50 % completed | Elapsed time: 0.00 mins
#
# z = 9.221 | 62.68 % completed | Elapsed time: 0.00 mins
#
# z = 9.229 | 62.86 % completed | Elapsed time: 0.00 mins
#
# z = 9.237 | 63.04 % completed | Elapsed time: 0.00 mins
#
# z = 9.245 | 63.22 % completed | Elapsed time: 0.00 mins
#
# z = 9.252 | 63.41 % completed | Elapsed time: 0.00 mins
#
# z = 9.260 | 63.59 % completed | Elapsed time: 0.00 mins
#
# z = 9.268 | 63.77 % completed | Elapsed time: 0.00 mins
#
# z = 9.276 | 63.95 % completed | Elapsed time: 0.00 mins
#
# z = 9.283 | 64.13 % completed | Elapsed time: 0.00 mins
#
# z = 9.291 | 64.31 % completed | Elapsed time: 0.00 mins
#
# z = 9.299 | 64.49 % completed | Elapsed time: 0.00 mins
#
# z = 9.307 | 64.67 % completed | Elapsed time: 0.00 mins
#
# z = 9.315 | 64.86 % completed | Elapsed time: 0.00 mins
#
# z = 9.322 | 65.04 % completed | Elapsed time: 0.00 mins
#
# z = 9.330 | 65.22 % completed | Elapsed time: 0.00 mins
#
# z = 9.338 | 65.40 % completed | Elapsed time: 0.00 mins
#
# z = 9.346 | 65.58 % completed | Elapsed time: 0.00 mins
#
# z = 9.354 | 65.76 % completed | Elapsed time: 0.00 mins
#
# z = 9.362 | 65.94 % completed | Elapsed time: 0.00 mins
#
# z = 9.370 | 66.12 % completed | Elapsed time: 0.00 mins
#
# z = 9.377 | 66.30 % completed | Elapsed time: 0.00 mins
#
# z = 9.385 | 66.49 % completed | Elapsed time: 0.00 mins
#
# z = 9.393 | 66.67 % completed | Elapsed time: 0.00 mins
#
# z = 9.401 | 66.85 % completed | Elapsed time: 0.00 mins
#
# z = 9.409 | 67.03 % completed | Elapsed time: 0.00 mins
#
# z = 9.417 | 67.21 % completed | Elapsed time: 0.00 mins
#
# z = 9.425 | 67.39 % completed | Elapsed time: 0.00 mins
#
# z = 9.433 | 67.57 % completed | Elapsed time: 0.00 mins
#
# z = 9.441 | 67.75 % completed | Elapsed time: 0.00 mins
#
# z = 9.449 | 67.93 % completed | Elapsed time: 0.00 mins
#
# z = 9.457 | 68.12 % completed | Elapsed time: 0.00 mins
#
# z = 9.465 | 68.30 % completed | Elapsed time: 0.00 mins
#
# z = 9.473 | 68.48 % completed | Elapsed time: 0.00 mins
#
# z = 9.481 | 68.66 % completed | Elapsed time: 0.00 mins
#
# z = 9.489 | 68.84 % completed | Elapsed time: 0.00 mins
#
# z = 9.497 | 69.02 % completed | Elapsed time: 0.00 mins
#
# z = 9.505 | 69.20 % completed | Elapsed time: 0.00 mins
#
# z = 9.513 | 69.38 % completed | Elapsed time: 0.00 mins
#
# z = 9.521 | 69.57 % completed | Elapsed time: 0.00 mins
#
# z = 9.529 | 69.75 % completed | Elapsed time: 0.00 mins
#
# z = 9.537 | 69.93 % completed | Elapsed time: 0.00 mins
#
# z = 9.545 | 70.11 % completed | Elapsed time: 0.00 mins
#
# z = 9.553 | 70.29 % completed | Elapsed time: 0.00 mins
#
# z = 9.562 | 70.47 % completed | Elapsed time: 0.00 mins
#
# z = 9.570 | 70.65 % completed | Elapsed time: 0.00 mins
#
# z = 9.578 | 70.83 % completed | Elapsed time: 0.00 mins
#
# z = 9.586 | 71.01 % completed | Elapsed time: 0.00 mins
#
# z = 9.594 | 71.20 % completed | Elapsed time: 0.00 mins
#
# z = 9.602 | 71.38 % completed | Elapsed time: 0.00 mins
#
# z = 9.610 | 71.56 % completed | Elapsed time: 0.00 mins
#
# z = 9.619 | 71.74 % completed | Elapsed time: 0.00 mins
#
# z = 9.627 | 71.92 % completed | Elapsed time: 0.00 mins
#
# z = 9.635 | 72.10 % completed | Elapsed time: 0.00 mins
#
# z = 9.643 | 72.28 % completed | Elapsed time: 0.00 mins
#
# z = 9.651 | 72.46 % completed | Elapsed time: 0.00 mins
#
# z = 9.659 | 72.64 % completed | Elapsed time: 0.00 mins
#
# z = 9.668 | 72.83 % completed | Elapsed time: 0.00 mins
#
# z = 9.676 | 73.01 % completed | Elapsed time: 0.00 mins
#
# z = 9.684 | 73.19 % completed | Elapsed time: 0.00 mins
#
# z = 9.692 | 73.37 % completed | Elapsed time: 0.00 mins
#
# z = 9.701 | 73.55 % completed | Elapsed time: 0.00 mins
#
# z = 9.709 | 73.73 % completed | Elapsed time: 0.00 mins
#
# z = 9.717 | 73.91 % completed | Elapsed time: 0.00 mins
#
# z = 9.726 | 74.09 % completed | Elapsed time: 0.00 mins
#
# z = 9.734 | 74.28 % completed | Elapsed time: 0.00 mins
#
# z = 9.742 | 74.46 % completed | Elapsed time: 0.00 mins
#
# z = 9.750 | 74.64 % completed | Elapsed time: 0.00 mins
#
# z = 9.759 | 74.82 % completed | Elapsed time: 0.00 mins
#
# z = 9.767 | 75.00 % completed | Elapsed time: 0.00 mins
#
# z = 9.776 | 75.18 % completed | Elapsed time: 0.00 mins
#
# z = 9.784 | 75.36 % completed | Elapsed time: 0.00 mins
#
# z = 9.792 | 75.54 % completed | Elapsed time: 0.00 mins
#
# z = 9.801 | 75.72 % completed | Elapsed time: 0.00 mins
#
# z = 9.809 | 75.91 % completed | Elapsed time: 0.00 mins
#
# z = 9.817 | 76.09 % completed | Elapsed time: 0.00 mins
#
# z = 9.826 | 76.27 % completed | Elapsed time: 0.00 mins
#
# z = 9.834 | 76.45 % completed | Elapsed time: 0.00 mins
#
# z = 9.843 | 76.63 % completed | Elapsed time: 0.00 mins
#
# z = 9.851 | 76.81 % completed | Elapsed time: 0.00 mins
#
# z = 9.860 | 76.99 % completed | Elapsed time: 0.00 mins
#
# z = 9.868 | 77.17 % completed | Elapsed time: 0.00 mins
#
# z = 9.876 | 77.36 % completed | Elapsed time: 0.00 mins
#
# z = 9.885 | 77.54 % completed | Elapsed time: 0.00 mins
#
# z = 9.893 | 77.72 % completed | Elapsed time: 0.00 mins
#
# z = 9.902 | 77.90 % completed | Elapsed time: 0.00 mins
#
# z = 9.910 | 78.08 % completed | Elapsed time: 0.00 mins
#
# z = 9.919 | 78.26 % completed | Elapsed time: 0.00 mins
#
# z = 9.927 | 78.44 % completed | Elapsed time: 0.00 mins
#
# z = 9.936 | 78.62 % completed | Elapsed time: 0.00 mins
#
# z = 9.945 | 78.80 % completed | Elapsed time: 0.00 mins
#
# z = 9.953 | 78.99 % completed | Elapsed time: 0.00 mins
#
# z = 9.962 | 79.17 % completed | Elapsed time: 0.00 mins
#
# z = 9.970 | 79.35 % completed | Elapsed time: 0.00 mins
#
# z = 9.979 | 79.53 % completed | Elapsed time: 0.00 mins
#
# z = 9.987 | 79.71 % completed | Elapsed time: 0.00 mins
#
# z = 9.996 | 79.89 % completed | Elapsed time: 0.00 mins
#
# z = 10.005 | 80.07 % completed | Elapsed time: 0.00 mins
#
# z = 10.013 | 80.25 % completed | Elapsed time: 0.00 mins
#
# z = 10.022 | 80.43 % completed | Elapsed time: 0.00 mins
#
# z = 10.031 | 80.62 % completed | Elapsed time: 0.00 mins
#
# z = 10.039 | 80.80 % completed | Elapsed time: 0.00 mins
#
# z = 10.048 | 80.98 % completed | Elapsed time: 0.00 mins
#
# z = 10.057 | 81.16 % completed | Elapsed time: 0.00 mins
#
# z = 10.065 | 81.34 % completed | Elapsed time: 0.00 mins
#
# z = 10.074 | 81.52 % completed | Elapsed time: 0.00 mins
#
# z = 10.083 | 81.70 % completed | Elapsed time: 0.00 mins
#
# z = 10.091 | 81.88 % completed | Elapsed time: 0.00 mins
#
# z = 10.100 | 82.07 % completed | Elapsed time: 0.00 mins
#
# z = 10.109 | 82.25 % completed | Elapsed time: 0.00 mins
#
# z = 10.118 | 82.43 % completed | Elapsed time: 0.00 mins
#
# z = 10.126 | 82.61 % completed | Elapsed time: 0.00 mins
#
# z = 10.135 | 82.79 % completed | Elapsed time: 0.00 mins
#
# z = 10.144 | 82.97 % completed | Elapsed time: 0.00 mins
#
# z = 10.153 | 83.15 % completed | Elapsed time: 0.00 mins
#
# z = 10.162 | 83.33 % completed | Elapsed time: 0.00 mins
#
# z = 10.170 | 83.51 % completed | Elapsed time: 0.00 mins
#
# z = 10.179 | 83.70 % completed | Elapsed time: 0.00 mins
#
# z = 10.188 | 83.88 % completed | Elapsed time: 0.00 mins
#
# z = 10.197 | 84.06 % completed | Elapsed time: 0.00 mins
#
# z = 10.206 | 84.24 % completed | Elapsed time: 0.00 mins
#
# z = 10.215 | 84.42 % completed | Elapsed time: 0.00 mins
#
# z = 10.223 | 84.60 % completed | Elapsed time: 0.00 mins
#
# z = 10.232 | 84.78 % completed | Elapsed time: 0.00 mins
#
# z = 10.241 | 84.96 % completed | Elapsed time: 0.00 mins
#
# z = 10.250 | 85.14 % completed | Elapsed time: 0.00 mins
#
# z = 10.259 | 85.33 % completed | Elapsed time: 0.00 mins
#
# z = 10.268 | 85.51 % completed | Elapsed time: 0.00 mins
#
# z = 10.277 | 85.69 % completed | Elapsed time: 0.00 mins
#
# z = 10.286 | 85.87 % completed | Elapsed time: 0.00 mins
#
# z = 10.295 | 86.05 % completed | Elapsed time: 0.00 mins
#
# z = 10.304 | 86.23 % completed | Elapsed time: 0.00 mins
#
# z = 10.313 | 86.41 % completed | Elapsed time: 0.00 mins
#
# z = 10.322 | 86.59 % completed | Elapsed time: 0.00 mins
#
# z = 10.331 | 86.78 % completed | Elapsed time: 0.00 mins
#
# z = 10.340 | 86.96 % completed | Elapsed time: 0.00 mins
#
# z = 10.349 | 87.14 % completed | Elapsed time: 0.00 mins
#
# z = 10.358 | 87.32 % completed | Elapsed time: 0.00 mins
#
# z = 10.367 | 87.50 % completed | Elapsed time: 0.00 mins
#
# z = 10.376 | 87.68 % completed | Elapsed time: 0.00 mins
#
# z = 10.385 | 87.86 % completed | Elapsed time: 0.00 mins
#
# z = 10.394 | 88.04 % completed | Elapsed time: 0.00 mins
#
# z = 10.403 | 88.22 % completed | Elapsed time: 0.00 mins
#
# z = 10.412 | 88.41 % completed | Elapsed time: 0.00 mins
#
# z = 10.421 | 88.59 % completed | Elapsed time: 0.00 mins
#
# z = 10.431 | 88.77 % completed | Elapsed time: 0.00 mins
#
# z = 10.440 | 88.95 % completed | Elapsed time: 0.00 mins
#
# z = 10.449 | 89.13 % completed | Elapsed time: 0.00 mins
#
# z = 10.458 | 89.31 % completed | Elapsed time: 0.00 mins
#
# z = 10.467 | 89.49 % completed | Elapsed time: 0.00 mins
#
# z = 10.476 | 89.67 % completed | Elapsed time: 0.00 mins
#
# z = 10.486 | 89.86 % completed | Elapsed time: 0.00 mins
#
# z = 10.495 | 90.04 % completed | Elapsed time: 0.00 mins
#
# z = 10.504 | 90.22 % completed | Elapsed time: 0.00 mins
#
# z = 10.513 | 90.40 % completed | Elapsed time: 0.00 mins
#
# z = 10.522 | 90.58 % completed | Elapsed time: 0.00 mins
#
# z = 10.532 | 90.76 % completed | Elapsed time: 0.00 mins
#
# z = 10.541 | 90.94 % completed | Elapsed time: 0.00 mins
#
# z = 10.550 | 91.12 % completed | Elapsed time: 0.00 mins
#
# z = 10.559 | 91.30 % completed | Elapsed time: 0.00 mins
#
# z = 10.569 | 91.49 % completed | Elapsed time: 0.00 mins
#
# z = 10.578 | 91.67 % completed | Elapsed time: 0.00 mins
#
# z = 10.587 | 91.85 % completed | Elapsed time: 0.00 mins
#
# z = 10.597 | 92.03 % completed | Elapsed time: 0.00 mins
#
# z = 10.606 | 92.21 % completed | Elapsed time: 0.00 mins
#
# z = 10.615 | 92.39 % completed | Elapsed time: 0.00 mins
#
# z = 10.625 | 92.57 % completed | Elapsed time: 0.00 mins
#
# z = 10.634 | 92.75 % completed | Elapsed time: 0.00 mins
#
# z = 10.643 | 92.93 % completed | Elapsed time: 0.00 mins
#
# z = 10.653 | 93.12 % completed | Elapsed time: 0.00 mins
#
# z = 10.662 | 93.30 % completed | Elapsed time: 0.00 mins
#
# z = 10.672 | 93.48 % completed | Elapsed time: 0.00 mins
#
# z = 10.681 | 93.66 % completed | Elapsed time: 0.00 mins
#
# z = 10.690 | 93.84 % completed | Elapsed time: 0.00 mins
#
# z = 10.700 | 94.02 % completed | Elapsed time: 0.00 mins
#
# z = 10.709 | 94.20 % completed | Elapsed time: 0.00 mins
#
# z = 10.719 | 94.38 % completed | Elapsed time: 0.00 mins
#
# z = 10.728 | 94.57 % completed | Elapsed time: 0.00 mins
#
# z = 10.738 | 94.75 % completed | Elapsed time: 0.00 mins
#
# z = 10.747 | 94.93 % completed | Elapsed time: 0.00 mins
#
# z = 10.757 | 95.11 % completed | Elapsed time: 0.00 mins
#
# z = 10.766 | 95.29 % completed | Elapsed time: 0.00 mins
#
# z = 10.776 | 95.47 % completed | Elapsed time: 0.00 mins
#
# z = 10.785 | 95.65 % completed | Elapsed time: 0.00 mins
#
# z = 10.795 | 95.83 % completed | Elapsed time: 0.00 mins
#
# z = 10.805 | 96.01 % completed | Elapsed time: 0.00 mins
#
# z = 10.814 | 96.20 % completed | Elapsed time: 0.00 mins
#
# z = 10.824 | 96.38 % completed | Elapsed time: 0.00 mins
#
# z = 10.833 | 96.56 % completed | Elapsed time: 0.00 mins
#
# z = 10.843 | 96.74 % completed | Elapsed time: 0.00 mins
#
# z = 10.853 | 96.92 % completed | Elapsed time: 0.00 mins
#
# z = 10.862 | 97.10 % completed | Elapsed time: 0.00 mins
#
# z = 10.872 | 97.28 % completed | Elapsed time: 0.00 mins
#
# z = 10.882 | 97.46 % completed | Elapsed time: 0.00 mins
#
# z = 10.891 | 97.64 % completed | Elapsed time: 0.00 mins
#
# z = 10.901 | 97.83 % completed | Elapsed time: 0.00 mins
#
# z = 10.911 | 98.01 % completed | Elapsed time: 0.00 mins
#
# z = 10.920 | 98.19 % completed | Elapsed time: 0.00 mins
#
# z = 10.930 | 98.37 % completed | Elapsed time: 0.00 mins
#
# z = 10.940 | 98.55 % completed | Elapsed time: 0.00 mins
#
# z = 10.950 | 98.73 % completed | Elapsed time: 0.00 mins
#
# z = 10.959 | 98.91 % completed | Elapsed time: 0.00 mins
#
# z = 10.969 | 99.09 % completed | Elapsed time: 0.00 mins
#
# z = 10.979 | 99.28 % completed | Elapsed time: 0.00 mins
#
# z = 10.989 | 99.46 % completed | Elapsed time: 0.00 mins
#
# z = 10.999 | 99.64 % completed | Elapsed time: 0.00 mins
#
# z = 11.008 | 99.82 % completed | Elapsed time: 0.00 mins
#
# z = 11.018 | 100.00 % completed | Elapsed time: 0.00 mins
# Creating noise.
#
# z = 7.00000 | 0.18 % completed
#
# z = 7.00535 | 0.36 % completed
#
# z = 7.01071 | 0.54 % completed
#
# z = 7.01608 | 0.72 % completed
#
# z = 7.02145 | 0.91 % completed
#
# z = 7.02682 | 1.09 % completed
#
# z = 7.03220 | 1.27 % completed
#
# z = 7.03759 | 1.45 % completed
#
# z = 7.04298 | 1.63 % completed
#
# z = 7.04837 | 1.81 % completed
#
# z = 7.05378 | 1.99 % completed
#
# z = 7.05918 | 2.17 % completed
#
# z = 7.06460 | 2.36 % completed
#
# z = 7.07002 | 2.54 % completed
#
# z = 7.07544 | 2.72 % completed
#
# z = 7.08087 | 2.90 % completed
#
# z = 7.08630 | 3.08 % completed
#
# z = 7.09174 | 3.26 % completed
#
# z = 7.09719 | 3.44 % completed
#
# z = 7.10264 | 3.62 % completed
#
# z = 7.10810 | 3.80 % completed
#
# z = 7.11356 | 3.99 % completed
#
# z = 7.11902 | 4.17 % completed
#
# z = 7.12450 | 4.35 % completed
#
# z = 7.12998 | 4.53 % completed
#
# z = 7.13546 | 4.71 % completed
#
# z = 7.14095 | 4.89 % completed
#
# z = 7.14644 | 5.07 % completed
#
# z = 7.15195 | 5.25 % completed
#
# z = 7.15745 | 5.43 % completed
#
# z = 7.16296 | 5.62 % completed
#
# z = 7.16848 | 5.80 % completed
#
# z = 7.17400 | 5.98 % completed
#
# z = 7.17953 | 6.16 % completed
#
# z = 7.18507 | 6.34 % completed
#
# z = 7.19061 | 6.52 % completed
# z = 7.19615 | 6.70 % completed
#
# z = 7.20170 | 6.88 % completed
#
# z = 7.20726 | 7.07 % completed
#
# z = 7.21282 | 7.25 % completed
#
# z = 7.21839 | 7.43 % completed
#
# z = 7.22396 | 7.61 % completed
#
# z = 7.22954 | 7.79 % completed
#
# z = 7.23512 | 7.97 % completed
#
# z = 7.24071 | 8.15 % completed
#
# z = 7.24631 | 8.33 % completed
#
# z = 7.25191 | 8.51 % completed
#
# z = 7.25752 | 8.70 % completed
#
# z = 7.26313 | 8.88 % completed
#
# z = 7.26875 | 9.06 % completed
#
# z = 7.27438 | 9.24 % completed
#
# z = 7.28001 | 9.42 % completed
#
# z = 7.28564 | 9.60 % completed
#
# z = 7.29128 | 9.78 % completed
#
# z = 7.29693 | 9.96 % completed
#
# z = 7.30258 | 10.14 % completed
#
# z = 7.30824 | 10.33 % completed
#
# z = 7.31391 | 10.51 % completed
#
# z = 7.31958 | 10.69 % completed
#
# z = 7.32525 | 10.87 % completed
#
# z = 7.33094 | 11.05 % completed
#
# z = 7.33662 | 11.23 % completed
#
# z = 7.34232 | 11.41 % completed
#
# z = 7.34802 | 11.59 % completed
#
# z = 7.35372 | 11.78 % completed
#
# z = 7.35943 | 11.96 % completed
#
# z = 7.36515 | 12.14 % completed
#
# z = 7.37087 | 12.32 % completed
#
# z = 7.37660 | 12.50 % completed
#
# z = 7.38234 | 12.68 % completed
#
# z = 7.38808 | 12.86 % completed
#
# z = 7.39382 | 13.04 % completed
#
# z = 7.39957 | 13.22 % completed
#
# z = 7.40533 | 13.41 % completed
#
# z = 7.41110 | 13.59 % completed
#
# z = 7.41687 | 13.77 % completed
#
# z = 7.42264 | 13.95 % completed
#
# z = 7.42842 | 14.13 % completed
#
# z = 7.43421 | 14.31 % completed
#
# z = 7.44000 | 14.49 % completed
#
# z = 7.44580 | 14.67 % completed
#
# z = 7.45161 | 14.86 % completed
#
# z = 7.45742 | 15.04 % completed
#
# z = 7.46324 | 15.22 % completed
#
# z = 7.46906 | 15.40 % completed
#
# z = 7.47489 | 15.58 % completed
#
# z = 7.48072 | 15.76 % completed
#
# z = 7.48657 | 15.94 % completed
#
# z = 7.49241 | 16.12 % completed
#
# z = 7.49827 | 16.30 % completed
#
# z = 7.50413 | 16.49 % completed
#
# z = 7.50999 | 16.67 % completed
#
# z = 7.51586 | 16.85 % completed
#
# z = 7.52174 | 17.03 % completed
#
# z = 7.52762 | 17.21 % completed
#
# z = 7.53351 | 17.39 % completed
#
# z = 7.53941 | 17.57 % completed
#
# z = 7.54531 | 17.75 % completed
#
# z = 7.55122 | 17.93 % completed
#
# z = 7.55713 | 18.12 % completed
#
# z = 7.56305 | 18.30 % completed
#
# z = 7.56898 | 18.48 % completed
#
# z = 7.57491 | 18.66 % completed
#
# z = 7.58085 | 18.84 % completed
#
# z = 7.58680 | 19.02 % completed
#
# z = 7.59275 | 19.20 % completed
#
# z = 7.59870 | 19.38 % completed
#
# z = 7.60467 | 19.57 % completed
#
# z = 7.61064 | 19.75 % completed
#
# z = 7.61661 | 19.93 % completed
#
# z = 7.62259 | 20.11 % completed
#
# z = 7.62858 | 20.29 % completed
#
# z = 7.63458 | 20.47 % completed
#
# z = 7.64058 | 20.65 % completed
#
# z = 7.64658 | 20.83 % completed
#
# z = 7.65260 | 21.01 % completed
#
# z = 7.65861 | 21.20 % completed
#
# z = 7.66464 | 21.38 % completed
#
# z = 7.67067 | 21.56 % completed
#
# z = 7.67671 | 21.74 % completed
#
# z = 7.68275 | 21.92 % completed
#
# z = 7.68880 | 22.10 % completed
#
# z = 7.69486 | 22.28 % completed
#
# z = 7.70092 | 22.46 % completed
#
# z = 7.70699 | 22.64 % completed
#
# z = 7.71307 | 22.83 % completed
#
# z = 7.71915 | 23.01 % completed
#
# z = 7.72524 | 23.19 % completed
#
# z = 7.73134 | 23.37 % completed
#
# z = 7.73744 | 23.55 % completed
#
# z = 7.74354 | 23.73 % completed
#
# z = 7.74966 | 23.91 % completed
#
# z = 7.75578 | 24.09 % completed
#
# z = 7.76191 | 24.28 % completed
#
# z = 7.76804 | 24.46 % completed
#
# z = 7.77418 | 24.64 % completed
#
# z = 7.78033 | 24.82 % completed
#
# z = 7.78648 | 25.00 % completed
#
# z = 7.79264 | 25.18 % completed
#
# z = 7.79880 | 25.36 % completed
#
# z = 7.80497 | 25.54 % completed
#
# z = 7.81115 | 25.72 % completed
#
# z = 7.81734 | 25.91 % completed
#
# z = 7.82353 | 26.09 % completed
#
# z = 7.82973 | 26.27 % completed
#
# z = 7.83593 | 26.45 % completed
#
# z = 7.84214 | 26.63 % completed
#
# z = 7.84836 | 26.81 % completed
#
# z = 7.85458 | 26.99 % completed
#
# z = 7.86081 | 27.17 % completed
#
# z = 7.86705 | 27.36 % completed
#
# z = 7.87330 | 27.54 % completed
#
# z = 7.87955 | 27.72 % completed
#
# z = 7.88580 | 27.90 % completed
#
# z = 7.89207 | 28.08 % completed
#
# z = 7.89834 | 28.26 % completed
#
# z = 7.90461 | 28.44 % completed
#
# z = 7.91090 | 28.62 % completed
#
# z = 7.91719 | 28.80 % completed
#
# z = 7.92348 | 28.99 % completed
#
# z = 7.92979 | 29.17 % completed
#
# z = 7.93609 | 29.35 % completed
#
# z = 7.94241 | 29.53 % completed
#
# z = 7.94873 | 29.71 % completed
#
# z = 7.95506 | 29.89 % completed
#
# z = 7.96140 | 30.07 % completed
#
# z = 7.96774 | 30.25 % completed
#
# z = 7.97409 | 30.43 % completed
#
# z = 7.98045 | 30.62 % completed
#
# z = 7.98681 | 30.80 % completed
#
# z = 7.99319 | 30.98 % completed
#
# z = 7.99956 | 31.16 % completed
#
# z = 8.00595 | 31.34 % completed
#
# z = 8.01234 | 31.52 % completed
#
# z = 8.01873 | 31.70 % completed
#
# z = 8.02514 | 31.88 % completed
#
# z = 8.03155 | 32.07 % completed
#
# z = 8.03797 | 32.25 % completed
#
# z = 8.04439 | 32.43 % completed
#
# z = 8.05082 | 32.61 % completed
#
# z = 8.05726 | 32.79 % completed
#
# z = 8.06371 | 32.97 % completed
#
# z = 8.07016 | 33.15 % completed
#
# z = 8.07662 | 33.33 % completed
#
# z = 8.08308 | 33.51 % completed
#
# z = 8.08956 | 33.70 % completed
#
# z = 8.09603 | 33.88 % completed
#
# z = 8.10252 | 34.06 % completed
#
# z = 8.10901 | 34.24 % completed
#
# z = 8.11551 | 34.42 % completed
#
# z = 8.12202 | 34.60 % completed
#
# z = 8.12854 | 34.78 % completed
#
# z = 8.13506 | 34.96 % completed
#
# z = 8.14159 | 35.14 % completed
#
# z = 8.14812 | 35.33 % completed
#
# z = 8.15466 | 35.51 % completed
#
# z = 8.16121 | 35.69 % completed
#
# z = 8.16777 | 35.87 % completed
#
# z = 8.17433 | 36.05 % completed
#
# z = 8.18090 | 36.23 % completed
#
# z = 8.18748 | 36.41 % completed
#
# z = 8.19406 | 36.59 % completed
#
# z = 8.20065 | 36.78 % completed
#
# z = 8.20725 | 36.96 % completed
#
# z = 8.21386 | 37.14 % completed
#
# z = 8.22047 | 37.32 % completed
#
# z = 8.22709 | 37.50 % completed
#
# z = 8.23372 | 37.68 % completed
#
# z = 8.24035 | 37.86 % completed
#
# z = 8.24699 | 38.04 % completed
#
# z = 8.25364 | 38.22 % completed
#
# z = 8.26030 | 38.41 % completed
#
# z = 8.26696 | 38.59 % completed
#
# z = 8.27363 | 38.77 % completed
#
# z = 8.28030 | 38.95 % completed
#
# z = 8.28699 | 39.13 % completed
#
# z = 8.29368 | 39.31 % completed
#
# z = 8.30038 | 39.49 % completed
#
# z = 8.30708 | 39.67 % completed
#
# z = 8.31380 | 39.86 % completed
#
# z = 8.32052 | 40.04 % completed
#
# z = 8.32724 | 40.22 % completed
#
# z = 8.33398 | 40.40 % completed
#
# z = 8.34072 | 40.58 % completed
#
# z = 8.34747 | 40.76 % completed
#
# z = 8.35423 | 40.94 % completed
#
# z = 8.36099 | 41.12 % completed
#
# z = 8.36776 | 41.30 % completed
#
# z = 8.37454 | 41.49 % completed
#
# z = 8.38133 | 41.67 % completed
#
# z = 8.38812 | 41.85 % completed
#
# z = 8.39492 | 42.03 % completed
#
# z = 8.40173 | 42.21 % completed
#
# z = 8.40854 | 42.39 % completed
#
# z = 8.41537 | 42.57 % completed
#
# z = 8.42220 | 42.75 % completed
#
# z = 8.42903 | 42.93 % completed
#
# z = 8.43588 | 43.12 % completed
#
# z = 8.44273 | 43.30 % completed
#
# z = 8.44959 | 43.48 % completed
#
# z = 8.45646 | 43.66 % completed
#
# z = 8.46333 | 43.84 % completed
#
# z = 8.47022 | 44.02 % completed
#
# z = 8.47711 | 44.20 % completed
#
# z = 8.48400 | 44.38 % completed
#
# z = 8.49091 | 44.57 % completed
#
# z = 8.49782 | 44.75 % completed
#
# z = 8.50474 | 44.93 % completed
#
# z = 8.51167 | 45.11 % completed
#
# z = 8.51860 | 45.29 % completed
#
# z = 8.52555 | 45.47 % completed
#
# z = 8.53250 | 45.65 % completed
#
# z = 8.53945 | 45.83 % completed
#
# z = 8.54642 | 46.01 % completed
#
# z = 8.55339 | 46.20 % completed
#
# z = 8.56037 | 46.38 % completed
#
# z = 8.56736 | 46.56 % completed
#
# z = 8.57436 | 46.74 % completed
#
# z = 8.58136 | 46.92 % completed
#
# z = 8.58837 | 47.10 % completed
#
# z = 8.59539 | 47.28 % completed
#
# z = 8.60242 | 47.46 % completed
#
# z = 8.60945 | 47.64 % completed
#
# z = 8.61649 | 47.83 % completed
#
# z = 8.62354 | 48.01 % completed
#
# z = 8.63060 | 48.19 % completed
#
# z = 8.63767 | 48.37 % completed
#
# z = 8.64474 | 48.55 % completed
#
# z = 8.65182 | 48.73 % completed
#
# z = 8.65891 | 48.91 % completed
#
# z = 8.66600 | 49.09 % completed
#
# z = 8.67311 | 49.28 % completed
#
# z = 8.68022 | 49.46 % completed
#
# z = 8.68734 | 49.64 % completed
#
# z = 8.69447 | 49.82 % completed
#
# z = 8.70160 | 50.00 % completed
#
# z = 8.70875 | 50.18 % completed
#
# z = 8.71590 | 50.36 % completed
#
# z = 8.72306 | 50.54 % completed
#
# z = 8.73022 | 50.72 % completed
#
# z = 8.73740 | 50.91 % completed
#
# z = 8.74458 | 51.09 % completed
#
# z = 8.75177 | 51.27 % completed
#
# z = 8.75897 | 51.45 % completed
#
# z = 8.76618 | 51.63 % completed
#
# z = 8.77339 | 51.81 % completed
#
# z = 8.78062 | 51.99 % completed
#
# z = 8.78785 | 52.17 % completed
#
# z = 8.79509 | 52.36 % completed
#
# z = 8.80233 | 52.54 % completed
#
# z = 8.80959 | 52.72 % completed
#
# z = 8.81685 | 52.90 % completed
#
# z = 8.82412 | 53.08 % completed
#
# z = 8.83140 | 53.26 % completed
#
# z = 8.83869 | 53.44 % completed
#
# z = 8.84598 | 53.62 % completed
#
# z = 8.85328 | 53.80 % completed
#
# z = 8.86060 | 53.99 % completed
#
# z = 8.86792 | 54.17 % completed
#
# z = 8.87524 | 54.35 % completed
#
# z = 8.88258 | 54.53 % completed
#
# z = 8.88992 | 54.71 % completed
#
# z = 8.89727 | 54.89 % completed
#
# z = 8.90463 | 55.07 % completed
#
# z = 8.91200 | 55.25 % completed
#
# z = 8.91938 | 55.43 % completed
#
# z = 8.92676 | 55.62 % completed
#
# z = 8.93416 | 55.80 % completed
#
# z = 8.94156 | 55.98 % completed
#
# z = 8.94897 | 56.16 % completed
#
# z = 8.95639 | 56.34 % completed
#
# z = 8.96381 | 56.52 % completed
#
# z = 8.97125 | 56.70 % completed
#
# z = 8.97869 | 56.88 % completed
#
# z = 8.98614 | 57.07 % completed
#
# z = 8.99360 | 57.25 % completed
#
# z = 9.00107 | 57.43 % completed
#
# z = 9.00854 | 57.61 % completed
# z = 9.01603 | 57.79 % completed
#
# z = 9.02352 | 57.97 % completed
#
# z = 9.03102 | 58.15 % completed
#
# z = 9.03853 | 58.33 % completed
#
# z = 9.04605 | 58.51 % completed
#
# z = 9.05358 | 58.70 % completed
#
# z = 9.06111 | 58.88 % completed
#
# z = 9.06866 | 59.06 % completed
#
# z = 9.07621 | 59.24 % completed
#
# z = 9.08377 | 59.42 % completed
#
# z = 9.09134 | 59.60 % completed
#
# z = 9.09891 | 59.78 % completed
#
# z = 9.10650 | 59.96 % completed
#
# z = 9.11409 | 60.14 % completed
#
# z = 9.12170 | 60.33 % completed
#
# z = 9.12931 | 60.51 % completed
#
# z = 9.13693 | 60.69 % completed
#
# z = 9.14456 | 60.87 % completed
#
# z = 9.15220 | 61.05 % completed
#
# z = 9.15984 | 61.23 % completed
#
# z = 9.16750 | 61.41 % completed
#
# z = 9.17516 | 61.59 % completed
#
# z = 9.18283 | 61.78 % completed
#
# z = 9.19051 | 61.96 % completed
#
# z = 9.19820 | 62.14 % completed
#
# z = 9.20590 | 62.32 % completed
#
# z = 9.21361 | 62.50 % completed
#
# z = 9.22132 | 62.68 % completed
#
# z = 9.22904 | 62.86 % completed
#
# z = 9.23678 | 63.04 % completed
#
# z = 9.24452 | 63.22 % completed
#
# z = 9.25227 | 63.41 % completed
#
# z = 9.26003 | 63.59 % completed
#
# z = 9.26780 | 63.77 % completed
#
# z = 9.27557 | 63.95 % completed
#
# z = 9.28336 | 64.13 % completed
#
# z = 9.29115 | 64.31 % completed
#
# z = 9.29896 | 64.49 % completed
#
# z = 9.30677 | 64.67 % completed
#
# z = 9.31459 | 64.86 % completed
#
# z = 9.32242 | 65.04 % completed
#
# z = 9.33026 | 65.22 % completed
#
# z = 9.33811 | 65.40 % completed
#
# z = 9.34596 | 65.58 % completed
#
# z = 9.35383 | 65.76 % completed
#
# z = 9.36170 | 65.94 % completed
#
# z = 9.36959 | 66.12 % completed
#
# z = 9.37748 | 66.30 % completed
#
# z = 9.38538 | 66.49 % completed
#
# z = 9.39329 | 66.67 % completed
#
# z = 9.40121 | 66.85 % completed
#
# z = 9.40914 | 67.03 % completed
#
# z = 9.41708 | 67.21 % completed
#
# z = 9.42502 | 67.39 % completed
#
# z = 9.43298 | 67.57 % completed
#
# z = 9.44094 | 67.75 % completed
#
# z = 9.44892 | 67.93 % completed
#
# z = 9.45690 | 68.12 % completed
#
# z = 9.46489 | 68.30 % completed
#
# z = 9.47290 | 68.48 % completed
#
# z = 9.48091 | 68.66 % completed
#
# z = 9.48893 | 68.84 % completed
#
# z = 9.49696 | 69.02 % completed
#
# z = 9.50499 | 69.20 % completed
#
# z = 9.51304 | 69.38 % completed
#
# z = 9.52110 | 69.57 % completed
#
# z = 9.52916 | 69.75 % completed
#
# z = 9.53724 | 69.93 % completed
#
# z = 9.54532 | 70.11 % completed
#
# z = 9.55342 | 70.29 % completed
#
# z = 9.56152 | 70.47 % completed
#
# z = 9.56963 | 70.65 % completed
#
# z = 9.57775 | 70.83 % completed
#
# z = 9.58589 | 71.01 % completed
#
# z = 9.59403 | 71.20 % completed
#
# z = 9.60218 | 71.38 % completed
#
# z = 9.61034 | 71.56 % completed
#
# z = 9.61850 | 71.74 % completed
#
# z = 9.62668 | 71.92 % completed
#
# z = 9.63487 | 72.10 % completed
#
# z = 9.64307 | 72.28 % completed
#
# z = 9.65127 | 72.46 % completed
#
# z = 9.65949 | 72.64 % completed
#
# z = 9.66771 | 72.83 % completed
#
# z = 9.67595 | 73.01 % completed
#
# z = 9.68419 | 73.19 % completed
#
# z = 9.69245 | 73.37 % completed
#
# z = 9.70071 | 73.55 % completed
#
# z = 9.70899 | 73.73 % completed
#
# z = 9.71727 | 73.91 % completed
#
# z = 9.72556 | 74.09 % completed
#
# z = 9.73386 | 74.28 % completed
#
# z = 9.74217 | 74.46 % completed
#
# z = 9.75050 | 74.64 % completed
#
# z = 9.75883 | 74.82 % completed
#
# z = 9.76717 | 75.00 % completed
#
# z = 9.77552 | 75.18 % completed
#
# z = 9.78388 | 75.36 % completed
#
# z = 9.79225 | 75.54 % completed
#
# z = 9.80063 | 75.72 % completed
#
# z = 9.80902 | 75.91 % completed
#
# z = 9.81741 | 76.09 % completed
#
# z = 9.82582 | 76.27 % completed
#
# z = 9.83424 | 76.45 % completed
#
# z = 9.84267 | 76.63 % completed
#
# z = 9.85111 | 76.81 % completed
#
# z = 9.85956 | 76.99 % completed
#
# z = 9.86801 | 77.17 % completed
#
# z = 9.87648 | 77.36 % completed
#
# z = 9.88496 | 77.54 % completed
#
# z = 9.89345 | 77.72 % completed
#
# z = 9.90194 | 77.90 % completed
#
# z = 9.91045 | 78.08 % completed
#
# z = 9.91897 | 78.26 % completed
#
# z = 9.92750 | 78.44 % completed
#
# z = 9.93603 | 78.62 % completed
#
# z = 9.94458 | 78.80 % completed
#
# z = 9.95314 | 78.99 % completed
#
# z = 9.96171 | 79.17 % completed
#
# z = 9.97028 | 79.35 % completed
#
# z = 9.97887 | 79.53 % completed
#
# z = 9.98747 | 79.71 % completed
#
# z = 9.99608 | 79.89 % completed
#
# z = 10.00469 | 80.07 % completed
#
# z = 10.01332 | 80.25 % completed
#
# z = 10.02196 | 80.43 % completed
#
# z = 10.03061 | 80.62 % completed
#
# z = 10.03927 | 80.80 % completed
#
# z = 10.04794 | 80.98 % completed
#
# z = 10.05661 | 81.16 % completed
#
# z = 10.06530 | 81.34 % completed
#
# z = 10.07400 | 81.52 % completed
#
# z = 10.08271 | 81.70 % completed
#
# z = 10.09143 | 81.88 % completed
#
# z = 10.10016 | 82.07 % completed
#
# z = 10.10890 | 82.25 % completed
#
# z = 10.11765 | 82.43 % completed
#
# z = 10.12641 | 82.61 % completed
#
# z = 10.13518 | 82.79 % completed
#
# z = 10.14397 | 82.97 % completed
#
# z = 10.15276 | 83.15 % completed
#
# z = 10.16156 | 83.33 % completed
#
# z = 10.17037 | 83.51 % completed
#
# z = 10.17920 | 83.70 % completed
#
# z = 10.18803 | 83.88 % completed
#
# z = 10.19688 | 84.06 % completed
#
# z = 10.20573 | 84.24 % completed
#
# z = 10.21460 | 84.42 % completed
#
# z = 10.22347 | 84.60 % completed
#
# z = 10.23236 | 84.78 % completed
#
# z = 10.24125 | 84.96 % completed
#
# z = 10.25016 | 85.14 % completed
#
# z = 10.25908 | 85.33 % completed
#
# z = 10.26801 | 85.51 % completed
#
# z = 10.27695 | 85.69 % completed
#
# z = 10.28590 | 85.87 % completed
#
# z = 10.29486 | 86.05 % completed
#
# z = 10.30383 | 86.23 % completed
#
# z = 10.31281 | 86.41 % completed
#
# z = 10.32180 | 86.59 % completed
#
# z = 10.33081 | 86.78 % completed
#
# z = 10.33982 | 86.96 % completed
#
# z = 10.34885 | 87.14 % completed
#
# z = 10.35788 | 87.32 % completed
#
# z = 10.36693 | 87.50 % completed
#
# z = 10.37598 | 87.68 % completed
#
# z = 10.38505 | 87.86 % completed
#
# z = 10.39413 | 88.04 % completed
#
# z = 10.40322 | 88.22 % completed
#
# z = 10.41232 | 88.41 % completed
#
# z = 10.42143 | 88.59 % completed
#
# z = 10.43056 | 88.77 % completed
#
# z = 10.43969 | 88.95 % completed
#
# z = 10.44883 | 89.13 % completed
#
# z = 10.45799 | 89.31 % completed
#
# z = 10.46715 | 89.49 % completed
#
# z = 10.47633 | 89.67 % completed
#
# z = 10.48552 | 89.86 % completed
#
# z = 10.49472 | 90.04 % completed
#
# z = 10.50393 | 90.22 % completed
#
# z = 10.51315 | 90.40 % completed
#
# z = 10.52238 | 90.58 % completed
#
# z = 10.53163 | 90.76 % completed
#
# z = 10.54088 | 90.94 % completed
#
# z = 10.55015 | 91.12 % completed
#
# z = 10.55942 | 91.30 % completed
#
# z = 10.56871 | 91.49 % completed
#
# z = 10.57801 | 91.67 % completed
#
# z = 10.58732 | 91.85 % completed
#
# z = 10.59664 | 92.03 % completed
#
# z = 10.60598 | 92.21 % completed
#
# z = 10.61532 | 92.39 % completed
#
# z = 10.62467 | 92.57 % completed
#
# z = 10.63404 | 92.75 % completed
#
# z = 10.64342 | 92.93 % completed
#
# z = 10.65281 | 93.12 % completed
#
# z = 10.66221 | 93.30 % completed
#
# z = 10.67162 | 93.48 % completed
#
# z = 10.68105 | 93.66 % completed
#
# z = 10.69048 | 93.84 % completed
#
# z = 10.69993 | 94.02 % completed
#
# z = 10.70939 | 94.20 % completed
#
# z = 10.71885 | 94.38 % completed
#
# z = 10.72834 | 94.57 % completed
#
# z = 10.73783 | 94.75 % completed
#
# z = 10.74733 | 94.93 % completed
#
# z = 10.75685 | 95.11 % completed
#
# z = 10.76637 | 95.29 % completed
#
# z = 10.77591 | 95.47 % completed
#
# z = 10.78546 | 95.65 % completed
#
# z = 10.79502 | 95.83 % completed
#
# z = 10.80460 | 96.01 % completed
#
# z = 10.81418 | 96.20 % completed
#
# z = 10.82378 | 96.38 % completed
#
# z = 10.83339 | 96.56 % completed
#
# z = 10.84301 | 96.74 % completed
#
# z = 10.85264 | 96.92 % completed
#
# z = 10.86228 | 97.10 % completed
#
# z = 10.87194 | 97.28 % completed
#
# z = 10.88161 | 97.46 % completed
#
# z = 10.89128 | 97.64 % completed
#
# z = 10.90098 | 97.83 % completed
#
# z = 10.91068 | 98.01 % completed
#
# z = 10.92039 | 98.19 % completed
#
# z = 10.93012 | 98.37 % completed
#
# z = 10.93986 | 98.55 % completed
#
# z = 10.94961 | 98.73 % completed
#
# z = 10.95937 | 98.91 % completed
#
# z = 10.96914 | 99.09 % completed
#
# z = 10.97893 | 99.28 % completed
#
# z = 10.98873 | 99.46 % completed
#
# z = 10.99854 | 99.64 % completed
#
# z = 11.00836 | 99.82 % completed
#
# z = 11.01819 | 100.00 % completed

# %%
#my_ext = [z_to_nu(z_quad[0]), z_to_nu(z_quad[-1]), 0, 500/0.7]     # freq axis
my_ext = [redshiftLC.min(), redshiftLC.max(), 0, params['BOX_LEN']]

fig, axes = plt.subplots(figsize=(25, 15))
gs = gridspec.GridSpec(3, 1)

ax0 = plt.subplot(gs[0])
im = ax0.imshow(mask_LCxH[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', aspect='auto', extent=my_ext)
ax0.set_ylabel('$Mpc$', size=16)
#ax0.tick_params(axis='both', length=7, width=1.5)
#plt.text(0.98, 0.95, models.loc['mean', 'name'], size=20, bbox=dict(facecolor='white', alpha=0.7), horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes)

dLC, _ = t2c.smooth_lightcone(lightcone=t2c.subtract_mean_signal(dataLC, los_axis=2), z_array=redshiftLC, box_size_mpc=params['BOX_LEN'])
ax1 = plt.subplot(gs[1])
im = ax1.imshow(dLC[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', aspect='auto', extent=my_ext)
ax1.set_ylabel('$Mpc$', size=16)


# THE SECOND SUBPLOT
ax2 = plt.subplot(gs[2])
im = ax2.imshow(LC3[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', aspect='auto', extent=my_ext)
ax2.set_ylabel('$Mpc$', size=16)
#ax1.tick_params(axis='both', length=7, width=1.5)
#plt.text(0.98, 0.95, models.loc['quadfit', 'name'], size=20, bbox=dict(facecolor='white', alpha=0.7), horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes)
# THE THIRT SUBPLOT
#ax2 = plt.subplot(gs[2])
#im = ax2.imshow(lightcone_scat[:,150,:len(z_quad)], cmap='plasma', extent=my_ext, aspect='auto')
#plt.text(0.98, 0.95, models.loc['scat', 'name'], size=20, bbox=dict(facecolor='white', alpha=0.7), horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes)
#plt.setp(ax0.get_xticklabels(), visible=False), plt.setp(ax1.get_xticklabels(), visible=False)

#ax1.set_ylabel('$Mpc/h$', size=16)
#ax1.set_xlabel(r'$\nu_{obs}$ [MHz]', size=16)
ax1.set_xlabel('z', size=16)
#ax2.tick_params(axis='both', length=7, width=1.5)

#im.set_clim(0., max([lightcone_mean.max(), lightcone_quad.max(), lightcone_scat.max()]))
#cbar = fig.colorbar(im, cax=fig.add_axes([0.92, 0.15, 0.03, 0.7]))
#cbar.set_label(r'$\delta T_b\,\, [mK]$', size=labels_size*0.8)

plt.subplots_adjust(hspace=0.01)
#plt.savefig(work_path+'plotLightcone_dTb.png', bbox_inches='tight')
#plt.savefig('plotLightcone_B2km_dTb.png', bbox_inches='tight')
plt.show()
plt.clf()

# %%
mask_LCxH.T.shape
# Out:
# (552, 128, 128)

# %% [markdown]
# ## Plot: Slice trough Lightcon

# %%
idx = 0 
my_ext = [0, params['BOX_LEN'], 0, params['BOX_LEN']]

#plt.title(r'z = %.3f   $\nu_{obs} = %.2f$ MHz'  %(redshiftLC[idx], t2c.z_to_nu(redshiftLC[idx])))
fig, axs = plt.subplots(ncols=2, sharey=True, figsize=(12,5))
plt.suptitle(r'z = %.3f     $\nu_{obs} = %.2f$ MHz'  %(redshiftLC[idx], t2c.z_to_nu(redshiftLC[idx])), size=16)
axs[0].set_title('mask $x_{HI}$')
axs[0].imshow(mask_LCxH[:,:,idx], origin='lower', cmap='jet', extent=my_ext, interpolation='nearest')
axs[1].set_title('$\delta T_b$')
im = axs[1].imshow(LC3[:,:,idx], origin='lower', cmap='jet', extent=my_ext, interpolation='nearest')
plt.colorbar(im)

# %% [markdown]
# ## Load SegUnet best model

# %%
import matplotlib.pyplot as plt, numpy as np
import tools21cm as t2c
from matplotlib import gridspec

plt.rcParams['font.size'] = 20
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.top'] = False
plt.rcParams['ytick.right'] = False
plt.rcParams['axes.linewidth'] = 1.2
ls = 22

# %%
import pickle
from tensorflow.keras.models import load_model
from utils_network.metrics import r2score, precision, recall, iou, iou_loss, dice_coef, dice_coef_loss, phi_coef, balanced_cross_entropy
from config.net_config import PredictionConfig

def LoadSegUnetModel(cfile):
    with open('utils_network/avail_metrics.pkl', 'rb') as handle:
        data = handle.read()
        avail_metrics = pickle.loads(data)
    
    #avail_metrics = {'binary_accuracy':'binary_accuracy', 'iou':iou, 'dice_coef':dice_coef, 'iou_loss':iou_loss, 'dice_coef_loss':dice_coef_loss, 'phi_coef':phi_coef, 'mse':'mse', 'mae':'mae', 'binary_crossentropy':'binary_crossentropy', 'balanced_cross_entropy':balanced_cross_entropy}
    conf = PredictionConfig(conf_file)

    PATH_OUT = conf.path_out
    MODEL_EPOCH = conf.model_epoch
    METRICS = [avail_metrics[m] for m in np.append(conf.loss, conf.metrics)]
    cb = {func.__name__:func for func in METRICS if not isinstance(func, str)}
    model_loaded = load_model('%smodel-sem21cm_ep%d.h5' %(PATH_OUT+'checkpoints/', MODEL_EPOCH), custom_objects=cb)
    
    print(' Loaded model:\n %smodel-sem21cm_ep%d.h5' %(PATH_OUT, MODEL_EPOCH))
    return model_loaded

# %%
# load model
#conf_file = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/15-06T22-53-20_128LC/'
#conf_file += 'net2D_lc_full.ini'
#conf_file = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/18-06T19-38-57_128LC/'
#conf_file += 'net2D_lc.ini'
#conf_file = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/18-06T21-00-44_128LC_dT/'
conf_file = '/home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/04-05T17-27-51_128LC_dT/'
outpath = conf_file

conf_file += 'net2D_lc_dT.ini'

model = LoadSegUnetModel(conf_file)
# Out:
#  Loaded model:
#  /home/michele/Documents/PhD_Sussex/output/ML/dataset/outputs/04-05T17-27-51_128LC_dT/model-sem21cm_ep77.h5

# %%
def RescaleData(arr, a=-1, b=1):
    scaled_arr = (arr.astype(np.float32) - np.min(arr))/(np.max(arr) - np.min(arr)) * (b-a) + a
    return scaled_arr

y = RescaleData(arr=mask_LCxH, a=0, b=1).astype(int)
norm_LC3 = RescaleData(arr=LC3, a=0, b=1)

# SegUnet 2D
X_seg = np.empty_like(LC3)
for i in tqdm(range(X_seg.shape[-1])):
    X = norm_LC3[:,:,i]
    X = X[np.newaxis, ..., np.newaxis]
    X_seg[:,:,i] = model.predict(X, verbose=0).squeeze()
#X_seg = np.round(X_seg).astype(int)
# Out:
# 100%|██████████| 552/552 [00:50<00:00, 16.22it/s]

# %% [markdown]
# ## Calculate Prediction

# %%
# SegUnet
from utils.other_utils import RescaleData
from utils_network.prediction import SegUnet21cmPredict

X_tta = SegUnet21cmPredict(unet=model, x=LC3, TTA=True)
X_seg = np.round(np.mean(X_tta, axis=0))
# Out:
# 100%|██████████| 16/16 [01:49<00:00,  7.93s/it]

# %%
idx = 0
my_ext = [0, params['BOX_LEN'], 0, params['BOX_LEN']]

#plt.title(r'z = %.3f   $\nu_{obs} = %.2f$ MHz'  %(redshiftLC[idx], t2c.z_to_nu(redshiftLC[idx])))
fig, axs = plt.subplots(ncols=2, sharey=True, figsize=(12,5))
plt.suptitle(r'z = %.3f     $\nu_{obs} = %.2f$ MHz     $x_{HI}$ = %.3f'  %(redshiftLC[idx], t2c.z_to_nu(redshiftLC[idx]), np.mean(dataLC_xH[:,:,idx])), size=16)
axs[0].set_title('mask $x_{HI}$')
axs[0].contour(mask_LCxH[:,:,idx], colors='lime', levels=[0.5], extent=my_ext)
axs[0].imshow(X_seg[:,:,idx], origin='lower', cmap='jet', extent=my_ext, interpolation='nearest')
axs[1].set_title('$\delta T_b$')
axs[1].imshow(LC3[:,:,idx], origin='lower', cmap='jet', extent=my_ext, interpolation='nearest')
#axs[1].imshow(norm_LC3[:,:,idx], origin='lower', cmap='jet', extent=my_ext, interpolation='nearest')

# %%
dth, dnu = BoxQuantity(cL=256, z=7)
print(dth.to(u.deg))
# Out:
# 2.3422534828696966 deg

# %%
import matplotlib.ticker as plticker
import math

#my_ext = [z_to_nu(z_quad[0]), z_to_nu(z_quad[-1]), 0, 500/0.7]     # freq axis
my_ext = [redshiftLC.min(), redshiftLC.max(), 0, params['BOX_LEN']]
my_ext2 = [redshiftLC.min(), redshiftLC.max(), 0, dth.to(u.deg).value]

fig, axes = plt.subplots(figsize=(25, 15))
gs = gridspec.GridSpec(3, 1)

ax0 = plt.subplot(gs[0])
im = ax0.imshow(X_seg[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', aspect='auto', extent=my_ext)
#ax0.contour(mask_LCxH[:,params['HII_DIM']//2,:], colors='lime', levels=[0.5], extent=my_ext)
ax0.set_ylabel('y [Mpc]', size=16)
ax0.tick_params(axis='both', length=7, width=1.5)

ax2 = ax0.twiny()
plt.rcParams['xtick.top'] = False
ax2.imshow(X_seg[:,params['HII_DIM']//2,:], cmap='jet', aspect='auto', extent=my_ext, alpha=0)
ax2.set_xlabel(r'$\nu_{\rm obs}$ [MHz]', size=20)

freq = t2c.z_to_nu(redshiftLC)
f2 = np.arange(int(math.ceil(freq.min()/10.0))*10, int(math.ceil(freq.max()/10.0))*10, 10)[::-1]
idx = []
for j, n2 in enumerate(f2):
    for i, n in enumerate(freq):
        if(abs(n-n2) < 0.07):
            idx.append(i)
plt.xticks(idx)
ax2.set_xticklabels([int(round(freq[i_n])) for i_n in idx])

"""
ax3 = ax0.twinx()
ax3.imshow(X_seg[:,params['HII_DIM']//2,:], cmap='jet', aspect='auto', extent=my_ext2, alpha=0)
ax3.set_ylabel(r'$\theta$ [deg]', size=20)
ax3.yaxis.set_major_locator(plticker.MultipleLocator(base=0.5))
ax3.yaxis.set_minor_locator(plticker.MultipleLocator(base=0.1))
"""
# THE SECOND SUBPLOT
dLC, _ = t2c.smooth_lightcone(lightcone=t2c.subtract_mean_signal(dataLC, los_axis=2), z_array=redshiftLC, box_size_mpc=params['BOX_LEN'])
dLC = RescaleData(arr=dLC, a=0, b=1)
ax3 = plt.subplot(gs[1])
im = ax3.imshow(dLC[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', aspect='auto', extent=my_ext)

# THE THIRT SUBPLOT
ax1 = plt.subplot(gs[2])
im = ax1.imshow(LC3[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', aspect='auto', extent=my_ext)
ax1.contour(mask_LCxH[:,params['HII_DIM']//2,:], colors='k', levels=[0.5], extent=my_ext)
ax1.set_ylabel('y [Mpc]', size=16)
ax1.tick_params(axis='both', length=7, width=1.5)
#fig.colorbar(im, ax=ax1, pad=0.01, fraction=0.048)
#fig.colorbar(im, label=r'$\delta T_{\rm b}$ [mK]', ax=ax1, pad=0.02, cax=fig.add_axes([0.905, 0.13, 0.01, 0.35]))
fig.colorbar(im, label=r'$\delta T_{\rm b}$ [mK]', ax=ax1, pad=0.02, cax=fig.add_axes([0.905, 0.13, 0.01, 0.25]))


#plt.text(0.98, 0.95, models.loc['quadfit', 'name'], size=20, bbox=dict(facecolor='white', alpha=0.7), horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes)
#ax2 = plt.subplot(gs[2])
#im = ax2.imshow(lightcone_scat[:,150,:len(z_quad)], cmap='plasma', extent=my_ext, aspect='auto')
#plt.text(0.98, 0.95, models.loc['scat', 'name'], size=20, bbox=dict(facecolor='white', alpha=0.7), horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes)
#plt.setp(ax0.get_xticklabels(), visible=False), plt.setp(ax1.get_xticklabels(), visible=False)

#ax1.set_ylabel('$Mpc/h$', size=16)
#ax1.set_xlabel(r'$\nu_{obs}$ [MHz]', size=16)
ax1.set_xlabel('z', size=16)
#ax2.tick_params(axis='both', length=7, width=1.5)

#im.set_clim(0., max([lightcone_mean.max(), lightcone_quad.max(), lightcone_scat.max()]))
#cbar = fig.colorbar(im, cax=fig.add_axes([0.92, 0.15, 0.03, 0.7]))
#cbar.set_label(r'$\delta T_b\,\, [mK]$', size=labels_size*0.8)

ax0.xaxis.set_minor_locator(plticker.MultipleLocator(base=0.1))
ax0.xaxis.set_major_locator(plticker.MultipleLocator(base=0.5))
ax1.xaxis.set_minor_locator(plticker.MultipleLocator(base=0.1))
ax1.xaxis.set_major_locator(plticker.MultipleLocator(base=0.5))
ax0.yaxis.set_major_locator(plticker.MultipleLocator(base=50))
ax0.yaxis.set_minor_locator(plticker.MultipleLocator(base=10))
ax1.yaxis.set_major_locator(plticker.MultipleLocator(base=50))
ax1.yaxis.set_minor_locator(plticker.MultipleLocator(base=10))

plt.subplots_adjust(hspace=0.05)
plt.savefig(outpath+'predictions/plotLightcone_B2km_dTb.png', bbox_inches='tight')
plt.show()
plt.clf()

# %%
# super-pixel
X = X_seg.squeeze()
labels = t2c.slic_cube(X.astype(dtype='float64'), n_segments=500, compactness=0.1, max_iter=20, sigma=0, min_size_factor=0.5, max_size_factor=3, cmap=None)
superpixel_map = t2c.superpixel_map(X, labels)
X_sp = 1-t2c.stitch_superpixels(X, labels, bins='knuth', binary=True, on_superpixel_map=True)
# Out:
# The output contains the labels created by SLIC with 509 segments

# %%
from sklearn.metrics import matthews_corrcoef

phicoef_seg = np.array([matthews_corrcoef(mask_LCxH[:,:,i].flatten(), X_seg[:,:,i].flatten()) for i in range(mask_LCxH.shape[-1])])
phicoef_sp = np.array([matthews_corrcoef(mask_LCxH[:,:,i].flatten(), X_sp[:,:,i].flatten()) for i in range(mask_LCxH.shape[-1])])

#xH_lc = np.array([np.mean(lightcone.xH_box[:,:,i]) for i in range(lightcone.xH_box.shape[-1])])
#print('mat_coef = %.3f\t(SegUnet)' %phicoef_seg)
#print('mat_coef = %.3f\t(Superpixel)' %phicoef_sp)

# %%
plt.figure(figsize=(12,9))
plt.plot(redshiftLC3, phicoef_seg, c='tab:blue', label='SegU-Net')
plt.plot(redshiftLC3, phicoef_sp, c='tab:orange', label='Super-Pixel')
plt.legend()
plt.ylabel(r'$\rm r_{\phi}$', size=20)
plt.xlabel(r'z', size=20)
plt.savefig(outpath+'predictions/plotLightcone_rphi.png', bbox_inches='tight')
plt.show()
plt.clf()

# %%
from sklearn.metrics import matthews_corrcoef

phicoef_seg = matthews_corrcoef(mask_LCxH.flatten(), X_seg.flatten())
phicoef_sp = matthews_corrcoef(mask_LCxH.flatten(), X_sp.flatten())

print('mat_coef = %.3f\t(SegUnet)' %phicoef_seg)
print('mat_coef = %.3f\t(Superpixel)' %phicoef_sp)
# Out:
# mat_coef = 0.542	(SegUnet)
# mat_coef = 0.540	(Superpixel)

# %%
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['figure.figsize'] = [20, 10]

idx = params['HII_DIM']//2

plt.subplot(121)
plt.title('Super-Pixel method ($r_{\phi}=%.3f$)' %phicoef_sp, size=ls)
plt.imshow(X_sp[:,idx,:], origin='lower', cmap='jet', extent=my_ext)
plt.contour(mask_LCxH[:,idx,:], colors='lime', levels=[0.5], extent=my_ext)
plt.xlabel('x [Mpc]'), plt.ylabel('y [Mpc]')
plt.subplot(122)
plt.title('Segmentation with SegUNet ($r_{\phi}=%.3f$)' %phicoef_seg, size=ls)
plt.imshow(X_seg[:,idx,:], origin='lower', cmap='jet', extent=my_ext)
plt.contour(mask_LCxH[:,idx,:], colors='lime', levels=[0.5], extent=my_ext)
plt.xlabel('x [Mpc]'), plt.ylabel('y [Mpc]')
#plt.savefig(outpath+'visual_comparison_240Mpc_z%.3f_r2.057.png' %z, bbox_inches='tight')
#plt.savefig(outpath+'visual_comparison_i%d.png' %index, bbox_inches='tight')
plt.show()
plt.clf()

# %% [markdown]
# ## SegUnet Standard-Deviation error

# %%
X_seg_err = np.std(X_tta, axis=0)

plt.figure(figsize=(10,5))
im = plt.imshow(X_seg_err[:,params['HII_DIM']//2,:], origin='lower', cmap='jet', extent=my_ext, interpolation='nearest')
plt.colorbar(im, label=r'$\sigma_{std}$')
plt.xlabel('x [Mpc]'), plt.ylabel('y [Mpc]')
plt.savefig(outpath+'visual_error_i%d.png' %index, bbox_inches='tight')

# %% [markdown]
# ## BSD - MFP

# %%
mfp_pred_ml = t2c.bubble_stats.mfp(X_seg, xth=0.5, boxsize=params['BOX_LEN'], iterations=2000000, verbose=False, upper_lim=False, bins=None, r_min=None, r_max=None)
mfp_pred_sp = t2c.bubble_stats.mfp(X_sp, xth=0.5, boxsize=params['BOX_LEN'], iterations=2000000, verbose=False, upper_lim=False, bins=None, r_min=None, r_max=None)
mfp_true = t2c.bubble_stats.mfp(mask_xn, xth=0.5, boxsize=params['BOX_LEN'], iterations=2000000, verbose=False, upper_lim=False, bins=None, r_min=None, r_max=None)  

mfp_tta = np.zeros((X_tta.shape[0], 2, 128))
for i in tqdm(range(0, X_tta.shape[0])):
    mfp_pred_ml1, mfp_pred_ml2 = t2c.bubble_stats.mfp(np.round(X_tta[i]), xth=0.5, boxsize=params['BOX_LEN'], iterations=2000000, verbose=False, upper_lim=False, bins=None, r_min=None, r_max=None)
    mfp_tta[i,0] = mfp_pred_ml1
    mfp_tta[i,1] = mfp_pred_ml2
# Out:
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
# Program runtime: 0.421177 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
# Program runtime: 0.444500 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   0%|          | 0/96 [00:00<?, ?it/s]
# Program runtime: 0.417171 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   1%|          | 1/96 [00:24<38:18, 24.19s/it]
# Program runtime: 0.403066 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   2%|▏         | 2/96 [00:49<38:39, 24.67s/it]
# Program runtime: 0.429716 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   3%|▎         | 3/96 [01:13<37:53, 24.44s/it]
# Program runtime: 0.398224 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   4%|▍         | 4/96 [01:38<37:32, 24.48s/it]
# Program runtime: 0.409178 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   5%|▌         | 5/96 [02:01<36:32, 24.10s/it]
# Program runtime: 0.386536 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   6%|▋         | 6/96 [02:28<37:25, 24.95s/it]
# Program runtime: 0.448987 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   7%|▋         | 7/96 [02:56<38:08, 25.72s/it]
# Program runtime: 0.458300 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   8%|▊         | 8/96 [03:24<39:02, 26.62s/it]
# Program runtime: 0.478419 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#   9%|▉         | 9/96 [03:50<38:20, 26.44s/it]
# Program runtime: 0.433867 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  10%|█         | 10/96 [04:17<37:54, 26.45s/it]
# Program runtime: 0.440873 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  11%|█▏        | 11/96 [04:42<37:07, 26.21s/it]
# Program runtime: 0.427298 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  12%|█▎        | 12/96 [05:10<37:25, 26.73s/it]
# Program runtime: 0.465750 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  14%|█▎        | 13/96 [05:35<36:13, 26.18s/it]
# Program runtime: 0.414923 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  15%|█▍        | 14/96 [06:03<36:30, 26.71s/it]
# Program runtime: 0.465579 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  16%|█▌        | 15/96 [06:28<35:25, 26.24s/it]
# Program runtime: 0.418711 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  17%|█▋        | 16/96 [06:55<35:08, 26.36s/it]
# Program runtime: 0.443794 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  18%|█▊        | 17/96 [07:19<33:56, 25.77s/it]
# Program runtime: 0.406677 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  19%|█▉        | 18/96 [07:44<33:04, 25.45s/it]
# Program runtime: 0.411216 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  20%|█▉        | 19/96 [08:08<32:10, 25.07s/it]
# Program runtime: 0.403103 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  21%|██        | 20/96 [08:33<31:40, 25.01s/it]
# Program runtime: 0.414417 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  22%|██▏       | 21/96 [08:57<30:39, 24.53s/it]
# Program runtime: 0.389634 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  23%|██▎       | 22/96 [09:21<30:08, 24.44s/it]
# Program runtime: 0.403700 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  24%|██▍       | 23/96 [09:44<29:18, 24.08s/it]
# Program runtime: 0.387500 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  25%|██▌       | 24/96 [10:09<29:18, 24.43s/it]
# Program runtime: 0.420411 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  26%|██▌       | 25/96 [10:34<28:50, 24.38s/it]
# Program runtime: 0.404270 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  27%|██▋       | 26/96 [10:57<28:15, 24.21s/it]
# Program runtime: 0.396986 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  28%|██▊       | 27/96 [11:21<27:38, 24.04s/it]
# Program runtime: 0.393703 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  29%|██▉       | 28/96 [11:45<27:08, 23.95s/it]
# Program runtime: 0.395515 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  30%|███       | 29/96 [12:12<27:45, 24.85s/it]
# Program runtime: 0.449060 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  31%|███▏      | 30/96 [12:36<27:14, 24.76s/it]
# Program runtime: 0.408931 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  32%|███▏      | 31/96 [13:04<27:41, 25.56s/it]
# Program runtime: 0.457029 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  33%|███▎      | 32/96 [13:29<27:05, 25.39s/it]
# Program runtime: 0.416562 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  34%|███▍      | 33/96 [13:53<26:10, 24.93s/it]
# Program runtime: 0.397054 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  35%|███▌      | 34/96 [14:17<25:36, 24.78s/it]
# Program runtime: 0.407066 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  36%|███▋      | 35/96 [14:45<26:07, 25.70s/it]
# Program runtime: 0.464264 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  38%|███▊      | 36/96 [15:09<25:18, 25.31s/it]
# Program runtime: 0.406519 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  39%|███▊      | 37/96 [15:33<24:30, 24.92s/it]
# Program runtime: 0.399763 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  40%|███▉      | 38/96 [16:00<24:30, 25.35s/it]
# Program runtime: 0.439053 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  41%|████      | 39/96 [16:24<23:52, 25.13s/it]
# Program runtime: 0.410300 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  42%|████▏     | 40/96 [16:51<23:49, 25.53s/it]
# Program runtime: 0.440988 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  43%|████▎     | 41/96 [17:18<23:57, 26.13s/it]
# Program runtime: 0.458661 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  44%|████▍     | 42/96 [17:45<23:44, 26.37s/it]
# Program runtime: 0.448694 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)
# Completed: 100.0%
#  45%|████▍     | 43/96 [18:15<24:08, 27.32s/it]
# Program runtime: 0.492147 minutes.
# The output contains a tuple with three values: r, rdP/dr
# The curve has been normalized.
# MFP method applied on 3D data (ver 1.0)

# %%
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

compare_ml = 100*(mfp_pred_ml[1]/mfp_true[1] - 1.)
compare_ml_tta = 100*(mfp_tta[:,1,:]/mfp_true[1] - 1.)
compare_sp = 100*(mfp_pred_sp[1]/mfp_true[1] - 1.)

# PLOTS
fig, ax0 = plt.subplots(figsize=(12, 9))
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 1.8]) # set height ratios for sublots

# THE FIRST SUBPLOT
ax0 = plt.subplot(gs[0])
ax0.set_title('$z=%.3f$\t$x_n=%.3f$\t$r_{\phi}=%.3f$' %(z, np.mean(xH), phicoef_seg), fontsize=ls)
ax0.fill_between(mfp_pred_ml[0], np.min(mfp_tta[:,1,:], axis=0), np.max(mfp_tta[:,1,:], axis=0), color='tab:blue', alpha=0.2)
ax0.plot(mfp_pred_ml[0], mfp_pred_ml[1], '-', color='tab:blue', label='SegUNet', lw=2)
ax0.plot(mfp_pred_sp[0], mfp_pred_sp[1], '-', color='tab:orange', label='Super-Pixel', lw=2)
ax0.plot(mfp_true[0], mfp_true[1], 'k--', label='Ground true', lw=2)
ax0.legend(loc=0, borderpad=0.5)
ax0.tick_params(axis='both', length=7, width=1.2)
ax0.tick_params(axis='both', which='minor', length=5, width=1.2)
ax0.set_ylabel('RdP/dR', size=18), ax0.set_xlabel('R (Mpc)')

# THE SECOND SUBPLOT
ax1 = plt.subplot(gs[1], sharex=ax0)
ax1.plot(mfp_true[0], compare_ml, '-', lw=2)
ax1.plot(mfp_true[0], compare_sp, '-', lw=2)
ax1.plot(mfp_true[0], np.zeros_like(mfp_true[0]), 'k--', lw=2)
ax1.fill_between(mfp_true[0], np.min(compare_ml_tta, axis=0), np.max(compare_ml_tta, axis=0), color='tab:blue', alpha=0.2)
ax1.tick_params(axis='both', length=7, width=1.2, labelsize=15)
ax1.set_ylabel('difference (%)', size=15)
ax1.set_xlabel('R (Mpc)', size=18)

# PLOT SETUP
plt.setp(ax0.get_xticklabels(), visible=False)
plt.subplots_adjust(hspace=0.0)
ax1.tick_params(which='minor', axis='both', length=5, width=1.2)
#plt.savefig(outpath+'bs_comparison_240Mpc_z%.3f_r2.057.png' %z, bbox_inches='tight')
plt.savefig(outpath+'bs_comparison_i%d.png' %index, bbox_inches='tight')
plt.show(), plt.clf()
# Out:
# (None, None)

# %% [markdown]
# # Calculate the Power Spectra

# %%
ps_true, ks_true = t2c.power_spectrum_1d(mask_xn, kbins=20, box_dims=256, binning='log')
ps_pred_sp, ks_pred_sp = t2c.power_spectrum_1d(X_sp, kbins=20, box_dims=256, binning='log')
ps_pred_ml, ks_pred_ml = t2c.power_spectrum_1d(X_seg, kbins=20, box_dims=256, binning='log')

ps_tta = np.zeros((X_tta.shape[0],20))
for i in range(0,X_tta.shape[0]):
    ps_tta[i], ks_pred_ml = t2c.power_spectrum_1d(np.round(X_tta[i]), kbins=20, box_dims=256, binning='log')

# %%
compare_ml = 100*(ps_pred_ml/ps_true - 1.)
compare_ml_tta = 100*(ps_tta/ps_true - 1.)
compare_sp = 100*(ps_pred_sp/ps_true - 1.)

# %%
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

fig, ax = plt.subplots(figsize=(16, 12))
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 1.8])
ax0 = plt.subplot(gs[0])
ax0.set_title('$z=%.3f$\t$x_n=%.3f$\t$r_{\phi}=%.3f$' %(z, np.mean(xH), phicoef_seg), fontsize=ls)
ax0.fill_between(ks_pred_ml, np.min(ps_tta*ks_pred_ml**3/2/np.pi**2, axis=0), np.max(ps_tta*ks_pred_ml**3/2/np.pi**2, axis=0), color='tab:blue', alpha=0.2)
ax0.loglog(ks_pred_ml, ps_pred_ml*ks_pred_ml**3/2/np.pi**2, '-', color='tab:blue', label='SegUNet', lw=2)
ax0.loglog(ks_pred_sp, ps_pred_sp*ks_pred_sp**3/2/np.pi**2, '-', color='tab:orange', label='Super-Pixel', lw=2)
ax0.loglog(ks_true, ps_true*ks_true**3/2/np.pi**2, 'k--', label='Ground true', lw=2)
ax0.set_yscale('log')
# THE SECOND SUBPLOT 
ax1 = plt.subplot(gs[1], sharex=ax0)
ax1.semilogx(ks_true, compare_ml, '-', lw=2)
ax1.semilogx(ks_true, compare_sp, '-', lw=2)
ax1.semilogx(ks_true, np.zeros_like(ks_true), 'k--', lw=2)
ax1.fill_between(ks_true, np.min(compare_ml_tta, axis=0), np.max(compare_ml_tta, axis=0), color='tab:blue', alpha=0.2)

# PLOT SETUP
ax1.tick_params(axis='both', length=7, width=1.2, labelsize=15)
ax1.set_xlabel('k (Mpc$^{-1}$)'), ax0.set_ylabel('$\Delta^2_{xx}$')
ax1.set_ylabel('difference (%)', size=15)
ax0.tick_params(axis='both', length=10, width=1.2)
ax0.tick_params(which='minor', axis='both', length=5, width=1.2)
ax1.tick_params(which='minor', axis='both', length=5, width=1.2)
ax0.legend(loc=0, borderpad=0.5)
plt.setp(ax0.get_xticklabels(), visible=False)
#plt.savefig(outpath+'Pk_comparison_240Mpc_z%.3f_r2.057.png' %z, bbox_inches='tight')
plt.savefig(outpath+'Pk_comparison_i%d.png' %index, bbox_inches='tight')
plt.subplots_adjust(hspace=0.0)
plt.show()
plt.clf()
